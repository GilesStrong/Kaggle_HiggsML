# %% [markdown]
# # Day 6
# batch size 256 lr 1e-3, normed weighted, rotated, cartesian, preBN

# %% [markdown]
# ### Import modules

# %%
# %matplotlib inline
from __future__ import division
import sys
import os
os.environ['MKL_THREADING_LAYER']='GNU'
sys.path.append('../')
from Modules.Basics import *
from Modules.Class_Basics import *
# Out:
# /home/giles/anaconda2/lib/python2.7/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# Using Theano backend.

# %% [markdown]
# ## Options

# %%
classTrainFeatures = ['DER_mass_MMC', 'DER_mass_transverse_met_lep', 'DER_mass_vis', 'DER_pt_h', 'DER_deltaeta_jet_jet', 'DER_mass_jet_jet', 'DER_prodeta_jet_jet', 'DER_deltar_tau_lep', 'DER_pt_tot', 'DER_sum_pt', 'DER_pt_ratio_lep_tau', 'DER_met_phi_centrality', 'DER_lep_eta_centrality', 'PRI_met_pt', 'PRI_met_sumet', 'PRI_jet_num', 'PRI_jet_all_pt', 'PRI_tau_px', 'PRI_tau_py', 'PRI_tau_pz', 'PRI_lep_px', 'PRI_lep_pz', 'PRI_jet_leading_px', 'PRI_jet_leading_py', 'PRI_jet_leading_pz', 'PRI_jet_subleading_px', 'PRI_jet_subleading_py', 'PRI_jet_subleading_pz', 'PRI_met_px', 'PRI_met_py']
inputPipe, outputPipe = getPreProcPipes(normIn=True)
classModel = 'modelSwish'
varSet = "basic_rot_features"

nSplits = 10
ensembleSize = 10
ensembleMode = 'loss'

maxEpochs = 200
compileArgs = {'loss':'binary_crossentropy', 'optimizer':'adam', 'bn':'pre'}
trainParams = {'epochs' : 1, 'batch_size' : 256, 'verbose' : 0}
modelParams = {'version':classModel, 'nIn':len(classTrainFeatures), 'compileArgs':compileArgs}

print "\nTraining on", len(classTrainFeatures), "features:", [var for var in classTrainFeatures]
# Out:
# Training on 30 features: ['DER_mass_MMC', 'DER_mass_transverse_met_lep', 'DER_mass_vis', 'DER_pt_h', 'DER_deltaeta_jet_jet', 'DER_mass_jet_jet', 'DER_prodeta_jet_jet', 'DER_deltar_tau_lep', 'DER_pt_tot', 'DER_sum_pt', 'DER_pt_ratio_lep_tau', 'DER_met_phi_centrality', 'DER_lep_eta_centrality', 'PRI_met_pt', 'PRI_met_sumet', 'PRI_jet_num', 'PRI_jet_all_pt', 'PRI_tau_px', 'PRI_tau_py', 'PRI_tau_pz', 'PRI_lep_px', 'PRI_lep_pz', 'PRI_jet_leading_px', 'PRI_jet_leading_py', 'PRI_jet_leading_pz', 'PRI_jet_subleading_px', 'PRI_jet_subleading_py', 'PRI_jet_subleading_pz', 'PRI_met_px', 'PRI_met_py']

# %% [markdown]
# ## Import data

# %%
trainData = h5py.File(dirLoc + 'train.hdf5', "r+")
valData = h5py.File(dirLoc + 'val.hdf5', "r+")

# %% [markdown]
# ## Determine LR

# %%
lrFinder = batchLRFindClassifier(trainData, nSplits, getClassifier, modelParams, trainParams, lrBounds=[1e-5,1e-1], trainOnWeights=True, verbose=0)
# Out:
# 2 classes found, running in binary mode
#
#
# ______________________________________
# Training finished
# Cross-validation took 30.317s
# ______________________________________

# %%
compileArgs['lr'] = 1e-3

# %% [markdown]
# ## Train classifier

# %%
results, histories = batchTrainClassifier(trainData, nSplits, getClassifier, modelParams, trainParams, patience=60, cosAnnealMult=2, trainOnWeights=True, maxEpochs=maxEpochs, verbose=1)
# Out:
# Using cosine annealing
# Training using weights
# Running fold 1 / 10
# 2 classes found, running in binary mode
#
# 1 New best found: 4.27719188035e-05
# 2 New best found: 3.80671407992e-05
# 3 New best found: 3.70673324329e-05
# 4 New best found: 3.63074782816e-05
# 5 New best found: 3.52333154536e-05
# 6 New best found: 3.4999462585e-05
# 7 New best found: 3.48511314868e-05
# 9 New best found: 3.46326660219e-05
# 10 New best found: 3.45703214414e-05
# 11 New best found: 3.45491680386e-05
# 12 New best found: 3.40297149529e-05
# 13 New best found: 3.39111088548e-05
# 14 New best found: 3.38278890757e-05
# 15 New best found: 3.38005274975e-05
# 20 New best found: 3.37370634402e-05
# 21 New best found: 3.34420367045e-05
# 23 New best found: 3.33489427319e-05
# 26 New best found: 3.33404388579e-05
# 27 New best found: 3.32833043161e-05
# 28 New best found: 3.31944718899e-05
# 29 New best found: 3.31738656009e-05
# 30 New best found: 3.31532360407e-05
# 48 New best found: 3.2958063061e-05
# 52 New best found: 3.28606671805e-05
# 57 New best found: 3.281911394e-05
# 59 New best found: 3.27958691316e-05
# 60 New best found: 3.27843843216e-05
# 61 New best found: 3.27829537586e-05
# 62 New best found: 3.27648110689e-05
# 63 New best found: 3.27565219608e-05
# 95 New best found: 3.26680565472e-05
# 112 New best found: 3.26648197531e-05
# 113 New best found: 3.26001920143e-05
# 116 New best found: 3.25968044055e-05
# 125 New best found: 3.25948091973e-05
# 126 New best found: 3.2583507937e-05
# Early stopping after 186 epochs
# Score is: {'loss': 3.2583507936988615e-05, 'AUC': 0.10300268390196765, 'wAUC': 0.066250321832436621}
# Fold took 316.376s
#
# Running fold 2 / 10
# 1 New best found: 4.28068140866e-05
# 2 New best found: 3.74178664063e-05
# 3 New best found: 3.59363544955e-05
# 4 New best found: 3.50489124214e-05
# 5 New best found: 3.48834915834e-05
# 6 New best found: 3.42518100809e-05
# 7 New best found: 3.41428503476e-05
# 9 New best found: 3.41145636402e-05
# 10 New best found: 3.38626183247e-05
# 11 New best found: 3.38243842125e-05
# 12 New best found: 3.33259786653e-05
# 13 New best found: 3.31941622199e-05
# 21 New best found: 3.29538633067e-05
# 22 New best found: 3.28593106628e-05
# 25 New best found: 3.27814816728e-05
# 28 New best found: 3.27238217836e-05
# 29 New best found: 3.27180229467e-05
# 30 New best found: 3.2659327446e-05
# 44 New best found: 3.26439664804e-05
# 48 New best found: 3.24072958709e-05
# 56 New best found: 3.23650170394e-05
# 57 New best found: 3.22754430068e-05
# 58 New best found: 3.22500276363e-05
# 79 New best found: 3.22023546622e-05
# 97 New best found: 3.21882285766e-05
# 102 New best found: 3.21001655892e-05
# 111 New best found: 3.20450063749e-05
# 112 New best found: 3.20000886863e-05
# Early stopping after 172 epochs
# Score is: {'loss': 3.2000088686266066e-05, 'AUC': 0.10125133336653103, 'wAUC': 0.063990455650715816}
# Fold took 287.308s
#
# Running fold 3 / 10
# 1 New best found: 4.21310911912e-05
# 2 New best found: 3.64663915079e-05
# 3 New best found: 3.52346147792e-05
# 4 New best found: 3.47817333665e-05
# 5 New best found: 3.35498812323e-05
# 6 New best found: 3.31782558136e-05
# 7 New best found: 3.30326406915e-05
# 10 New best found: 3.26202773267e-05
# 11 New best found: 3.24930391686e-05
# 12 New best found: 3.23111635188e-05
# 14 New best found: 3.22741667256e-05
# 15 New best found: 3.22541374865e-05
# 18 New best found: 3.22282550016e-05
# 21 New best found: 3.21172273646e-05
# 22 New best found: 3.21105842511e-05
# 23 New best found: 3.19919244538e-05
# 24 New best found: 3.18977179254e-05
# 25 New best found: 3.17231621754e-05
# 27 New best found: 3.17087781132e-05
# 29 New best found: 3.16872275973e-05
# 30 New best found: 3.16227493618e-05
# 31 New best found: 3.16174247317e-05
# 43 New best found: 3.15137566718e-05
# 50 New best found: 3.14425562825e-05
# 52 New best found: 3.14199045864e-05
# 54 New best found: 3.14062605636e-05
# 56 New best found: 3.13361499812e-05
# 57 New best found: 3.12647378164e-05
# 97 New best found: 3.10687776627e-05
# 111 New best found: 3.10476953203e-05
# 120 New best found: 3.10438966124e-05
# Early stopping after 180 epochs
# Score is: {'loss': 3.1043896612375004e-05, 'AUC': 0.10040542604939229, 'wAUC': 0.060924753045223268}
# Fold took 306.995s
#
# Running fold 4 / 10
# 1 New best found: 4.28069783309e-05
# 2 New best found: 3.7721955615e-05
# 3 New best found: 3.63639683567e-05
# 4 New best found: 3.50338764483e-05
# 5 New best found: 3.44469407765e-05
# 6 New best found: 3.39031592168e-05
# 7 New best found: 3.38257743139e-05
# 9 New best found: 3.36708257588e-05
# 10 New best found: 3.35601583488e-05
# 11 New best found: 3.32220694438e-05
# 13 New best found: 3.30679098101e-05
# 14 New best found: 3.30306391729e-05
# 15 New best found: 3.30157091344e-05
# 18 New best found: 3.30131940308e-05
# 20 New best found: 3.26726259687e-05
# 23 New best found: 3.2645805594e-05
# 25 New best found: 3.23990448481e-05
# 28 New best found: 3.23977861752e-05
# 29 New best found: 3.23316370599e-05
# 30 New best found: 3.2322941715e-05
# 31 New best found: 3.23174426353e-05
# 44 New best found: 3.23036684526e-05
# 46 New best found: 3.22828414323e-05
# 47 New best found: 3.21819915833e-05
# 51 New best found: 3.20552864583e-05
# 52 New best found: 3.20152678951e-05
# 53 New best found: 3.20028773343e-05
# 56 New best found: 3.19461889329e-05
# 60 New best found: 3.19406233721e-05
# 61 New best found: 3.19386437986e-05
# 89 New best found: 3.19090804138e-05
# 97 New best found: 3.18873879057e-05
# 101 New best found: 3.18674387068e-05
# 106 New best found: 3.18052598834e-05
# 107 New best found: 3.17583532146e-05
# 119 New best found: 3.1740110005e-05
# Early stopping after 179 epochs
# Score is: {'loss': 3.1740110004980193e-05, 'AUC': 0.10050688327757418, 'wAUC': 0.063396603637813964}
# Fold took 298.978s
#
# Running fold 5 / 10
# 1 New best found: 4.4417326629e-05
# 2 New best found: 3.85610356585e-05
# 3 New best found: 3.7062150513e-05
# 4 New best found: 3.62039455658e-05
# 5 New best found: 3.55393391391e-05
# 6 New best found: 3.48460464153e-05
# 7 New best found: 3.47136765328e-05
# 10 New best found: 3.46431718612e-05
# 11 New best found: 3.40439075015e-05
# 12 New best found: 3.40259894943e-05
# 13 New best found: 3.37473142109e-05
# 14 New best found: 3.36317854114e-05
# 20 New best found: 3.35824252017e-05
# 21 New best found: 3.33510791857e-05
# 23 New best found: 3.32886353797e-05
# 24 New best found: 3.32410784097e-05
# 27 New best found: 3.32028639386e-05
# 28 New best found: 3.31157310215e-05
# 29 New best found: 3.30979583017e-05
# 30 New best found: 3.30554739598e-05
# 31 New best found: 3.30499408275e-05
# 41 New best found: 3.30366711552e-05
# 43 New best found: 3.29804964839e-05
# 45 New best found: 3.28906525089e-05
# 48 New best found: 3.26899115791e-05
# 54 New best found: 3.26540086366e-05
# 57 New best found: 3.25888682775e-05
# 58 New best found: 3.25520604401e-05
# 59 New best found: 3.25352678365e-05
# 102 New best found: 3.25280291859e-05
# 103 New best found: 3.23994208576e-05
# 106 New best found: 3.23976173389e-05
# 111 New best found: 3.23743789664e-05
# 112 New best found: 3.23626048171e-05
# 113 New best found: 3.23599771834e-05
# 117 New best found: 3.23568203206e-05
# 120 New best found: 3.23560025195e-05
# 121 New best found: 3.23486710041e-05
# 122 New best found: 3.2341983964e-05
# Early stopping after 182 epochs
# Score is: {'loss': 3.2341983963987696e-05, 'AUC': 0.10280337118983496, 'wAUC': 0.065567642488008504}
# Fold took 307.623s
#
# Running fold 6 / 10
# 1 New best found: 4.26384823575e-05
# 2 New best found: 3.77031749684e-05
# 3 New best found: 3.64194972999e-05
# 5 New best found: 3.48083003574e-05
# 6 New best found: 3.45449303063e-05
# 7 New best found: 3.44190115326e-05
# 9 New best found: 3.42506898e-05
# 10 New best found: 3.37966617084e-05
# 11 New best found: 3.34558736159e-05
# 12 New best found: 3.34120776128e-05
# 15 New best found: 3.33538708768e-05
# 19 New best found: 3.32137917922e-05
# 21 New best found: 3.31299554059e-05
# 23 New best found: 3.29810485566e-05
# 25 New best found: 3.28508553373e-05
# 26 New best found: 3.27582910614e-05
# 28 New best found: 3.27316588285e-05
# 29 New best found: 3.26195315477e-05
# 43 New best found: 3.25695138999e-05
# 44 New best found: 3.25411723894e-05
# 49 New best found: 3.24223436502e-05
# 50 New best found: 3.24044889955e-05
# 54 New best found: 3.22696226997e-05
# 56 New best found: 3.21826147144e-05
# 62 New best found: 3.21793271094e-05
# 63 New best found: 3.21734060161e-05
# 92 New best found: 3.21610082403e-05
# 98 New best found: 3.21451611813e-05
# 99 New best found: 3.20115027651e-05
# 115 New best found: 3.19866629325e-05
# 119 New best found: 3.19752721933e-05
# Early stopping after 179 epochs
# Score is: {'loss': 3.1975272193261519e-05, 'AUC': 0.10138078702737041, 'wAUC': 0.063575317988377344}
# Fold took 298.146s
#
# Running fold 7 / 10
# 1 New best found: 4.33050581183e-05
# 2 New best found: 3.96504900427e-05
# 3 New best found: 3.75589191748e-05
# 4 New best found: 3.7478383564e-05
# 5 New best found: 3.54271032144e-05
# 6 New best found: 3.52892276825e-05
# 7 New best found: 3.52635959095e-05
# 9 New best found: 3.52601942559e-05
# 11 New best found: 3.4544499385e-05
# 12 New best found: 3.44346314616e-05
# 13 New best found: 3.43974252628e-05
# 14 New best found: 3.42134584825e-05
# 15 New best found: 3.42008933003e-05
# 21 New best found: 3.41735454675e-05
# 22 New best found: 3.40710491975e-05
# 23 New best found: 3.38729045083e-05
# 25 New best found: 3.38252882001e-05
# 26 New best found: 3.37817025224e-05
# 27 New best found: 3.36024095078e-05
# 48 New best found: 3.34924648479e-05
# 49 New best found: 3.3465555171e-05
# 50 New best found: 3.33025305737e-05
# 58 New best found: 3.3295206264e-05
# 59 New best found: 3.3271958992e-05
# 97 New best found: 3.32393511387e-05
# 98 New best found: 3.3214950674e-05
# 102 New best found: 3.32145077282e-05
# 104 New best found: 3.31723659818e-05
# 112 New best found: 3.31636278033e-05
# 113 New best found: 3.3084350971e-05
# 149 New best found: 3.30585511134e-05
# Early stopping after 209 epochs
# Score is: {'loss': 3.3058551113422531e-05, 'AUC': 0.10050797168678904, 'wAUC': 0.068484555250592605}
# Fold took 347.274s
#
# Running fold 8 / 10
# 1 New best found: 4.25579033635e-05
# 2 New best found: 3.7831701603e-05
# 3 New best found: 3.7036288102e-05
# 4 New best found: 3.62926144084e-05
# 5 New best found: 3.54683076487e-05
# 6 New best found: 3.50127223524e-05
# 7 New best found: 3.4760578914e-05
# 9 New best found: 3.46207256159e-05
# 10 New best found: 3.41553132653e-05
# 11 New best found: 3.39241184121e-05
# 13 New best found: 3.37400682982e-05
# 14 New best found: 3.36712823478e-05
# 15 New best found: 3.36310307605e-05
# 20 New best found: 3.35447743384e-05
# 21 New best found: 3.35414543672e-05
# 23 New best found: 3.33748752297e-05
# 26 New best found: 3.32077892958e-05
# 27 New best found: 3.31733935883e-05
# 28 New best found: 3.30283488372e-05
# 29 New best found: 3.3024062414e-05
# 30 New best found: 3.30222060609e-05
# 47 New best found: 3.29065566995e-05
# 48 New best found: 3.28778425221e-05
# 53 New best found: 3.28530606219e-05
# 54 New best found: 3.28332762795e-05
# 55 New best found: 3.27959555592e-05
# 57 New best found: 3.27444935925e-05
# 102 New best found: 3.26510785181e-05
# 112 New best found: 3.26492624264e-05
# 119 New best found: 3.26129783239e-05
# 122 New best found: 3.26029512794e-05
# Early stopping after 182 epochs
# Score is: {'loss': 3.2602951279387352e-05, 'AUC': 0.10811833332466925, 'wAUC': 0.066822514723014148}
# Fold took 305.704s
#
# Running fold 9 / 10
# 1 New best found: 4.25735576868e-05
# 2 New best found: 3.77172564839e-05
# 3 New best found: 3.64188040177e-05
# 4 New best found: 3.57265966599e-05
# 5 New best found: 3.45864657345e-05
# 6 New best found: 3.41872784462e-05
# 7 New best found: 3.4092122046e-05
# 10 New best found: 3.37716885865e-05
# 12 New best found: 3.35093942915e-05
# 13 New best found: 3.31324024766e-05
# 14 New best found: 3.31175215847e-05
# 15 New best found: 3.30950873448e-05
# 20 New best found: 3.30643531349e-05
# 23 New best found: 3.29206343003e-05
# 24 New best found: 3.25355171188e-05
# 26 New best found: 3.25344627347e-05
# 27 New best found: 3.24374653469e-05
# 29 New best found: 3.24056746172e-05
# 30 New best found: 3.23951507031e-05
# 31 New best found: 3.23561614645e-05
# 42 New best found: 3.23538571829e-05
# 44 New best found: 3.2350830994e-05
# 46 New best found: 3.23481829259e-05
# 47 New best found: 3.22954205139e-05
# 48 New best found: 3.22272295266e-05
# 49 New best found: 3.21046417244e-05
# 53 New best found: 3.20242022644e-05
# 55 New best found: 3.19613421009e-05
# 56 New best found: 3.19301711422e-05
# 58 New best found: 3.19157118583e-05
# 83 New best found: 3.19148455935e-05
# 91 New best found: 3.18853311012e-05
# 98 New best found: 3.18798045791e-05
# 100 New best found: 3.18046697613e-05
# 107 New best found: 3.17817569747e-05
# 109 New best found: 3.16924399855e-05
# 119 New best found: 3.16855312613e-05
# 120 New best found: 3.16625742445e-05
# 121 New best found: 3.16491399085e-05
# Early stopping after 181 epochs
# Score is: {'loss': 3.1649139908479274e-05, 'AUC': 0.099415385521784305, 'wAUC': 0.062474149511694943}
# Fold took 304.345s
#
# Running fold 10 / 10
# 1 New best found: 4.2263796208e-05
# 2 New best found: 3.72727694335e-05
# 3 New best found: 3.58289407528e-05
# 4 New best found: 3.55029983625e-05
# 5 New best found: 3.43827879174e-05
# 6 New best found: 3.37133704411e-05
# 7 New best found: 3.3611254149e-05
# 8 New best found: 3.35128424997e-05
# 11 New best found: 3.30334339862e-05
# 12 New best found: 3.28706495261e-05
# 13 New best found: 3.28312734302e-05
# 14 New best found: 3.27956788194e-05
# 15 New best found: 3.27627195233e-05
# 17 New best found: 3.26700778335e-05
# 24 New best found: 3.23891402554e-05
# 26 New best found: 3.21162490611e-05
# 27 New best found: 3.21080311496e-05
# 28 New best found: 3.20964814926e-05
# 29 New best found: 3.20652237113e-05
# 30 New best found: 3.20471666056e-05
# 43 New best found: 3.19794878812e-05
# 44 New best found: 3.18669422386e-05
# 46 New best found: 3.17876987241e-05
# 51 New best found: 3.1761048621e-05
# 52 New best found: 3.17423992965e-05
# 53 New best found: 3.16753039161e-05
# 54 New best found: 3.16148859823e-05
# 56 New best found: 3.16067385452e-05
# 57 New best found: 3.16047275279e-05
# 61 New best found: 3.16036331488e-05
# 62 New best found: 3.16026280129e-05
# 63 New best found: 3.15901194193e-05
# 80 New best found: 3.15800459656e-05
# 90 New best found: 3.15776754551e-05
# 96 New best found: 3.15711577701e-05
# 98 New best found: 3.14605670723e-05
# 99 New best found: 3.14457188018e-05
# 100 New best found: 3.13747190473e-05
# 107 New best found: 3.1372625673e-05
# 109 New best found: 3.13542499343e-05
# 110 New best found: 3.12988441146e-05
# 118 New best found: 3.12879776299e-05
# Early stopping after 178 epochs
# Score is: {'loss': 3.1287977629884043e-05, 'AUC': 0.093912295254193312, 'wAUC': 0.061482306817544297}
# Fold took 302.901s
#
#
# ______________________________________
# Training finished
# Cross-validation took 3076.143s
# Mean wAUC = 0.0643 +- 0.0007
# ______________________________________

# %% [markdown]
# ## Construct ensemble

# %%
with open('train_weights/resultsFile.pkl', 'r') as fin:   
    results = pickle.load(fin)

# %%
ensemble, weights = assembleEnsemble(results, ensembleSize, ensembleMode, compileArgs)
# Out:
# Choosing ensemble by loss
# Model 0 is 2 with loss = 3.10438966124e-05
# Model 1 is 9 with loss = 3.12879776299e-05
# Model 2 is 8 with loss = 3.16491399085e-05
# Model 3 is 3 with loss = 3.1740110005e-05
# Model 4 is 5 with loss = 3.19752721933e-05
# Model 5 is 1 with loss = 3.20000886863e-05
# Model 6 is 4 with loss = 3.2341983964e-05
# Model 7 is 0 with loss = 3.2583507937e-05
# Model 8 is 7 with loss = 3.26029512794e-05
# Model 9 is 6 with loss = 3.30585511134e-05

# %% [markdown]
# ## Response on development data

# %%
batchEnsemblePredict(ensemble, weights, trainData, ensembleSize=10, verbose=1)
# Out:
# Predicting batch 1 out of 10
# Prediction took 0.000596898703878s per sample
#
# Predicting batch 2 out of 10
# Prediction took 0.000338221292461s per sample
#
# Predicting batch 3 out of 10
# Prediction took 0.000355637328016s per sample
#
# Predicting batch 4 out of 10
# Prediction took 0.000326657605171s per sample
#
# Predicting batch 5 out of 10
# Prediction took 0.000331965792179s per sample
#
# Predicting batch 6 out of 10
# Prediction took 0.000348178648949s per sample
#
# Predicting batch 7 out of 10
# Prediction took 0.000345899307728s per sample
#
# Predicting batch 8 out of 10
# Prediction took 0.00033699254333s per sample
#
# Predicting batch 9 out of 10
# Prediction took 0.000333559823648s per sample
#
# Predicting batch 10 out of 10
# Prediction took 0.000337088595057s per sample

# %%
print 'Training ROC AUC: unweighted {}, weighted {}'.format(roc_auc_score(getFeature('targets', trainData), getFeature('pred', trainData)),
                                                            roc_auc_score(getFeature('targets', trainData), getFeature('pred', trainData), sample_weight=getFeature('weights', trainData)))
# Out:
# Training ROC AUC: unweighted 0.904024195343, weighted 0.940105716811

# %% [markdown]
# ## Response on val data

# %%
batchEnsemblePredict(ensemble, weights, valData, ensembleSize=10, verbose=1)
# Out:
# Predicting batch 1 out of 10
# Prediction took 0.000339554405212s per sample
#
# Predicting batch 2 out of 10
# Prediction took 0.000330009794235s per sample
#
# Predicting batch 3 out of 10
# Prediction took 0.000364728593826s per sample
#
# Predicting batch 4 out of 10
# Prediction took 0.000367620182037s per sample
#
# Predicting batch 5 out of 10
# Prediction took 0.000506412982941s per sample
#
# Predicting batch 6 out of 10
# Prediction took 0.000455235004425s per sample
#
# Predicting batch 7 out of 10
# Prediction took 0.000331489562988s per sample
#
# Predicting batch 8 out of 10
# Prediction took 0.000326723814011s per sample
#
# Predicting batch 9 out of 10
# Prediction took 0.000407542610168s per sample
#
# Predicting batch 10 out of 10
# Prediction took 0.000334997367859s per sample

# %%
print 'Testing ROC AUC: unweighted {}, weighted {}'.format(roc_auc_score(getFeature('targets', valData), getFeature('pred', valData)),
                                                           roc_auc_score(getFeature('targets', valData), getFeature('pred', valData), sample_weight=getFeature('weights', valData)))
# Out:
# Testing ROC AUC: unweighted 0.901044662043, weighted 0.934806656516

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ### Import in dataframe

# %%
valframe = convertToDF(valData)
# Out:
# 50000 candidates loaded

# %%
sigVal = (valframe.gen_target == 1)
bkgVal = (valframe.gen_target == 0)

# %% [markdown]
# ### MVA distributions

# %%
getClassPredPlot([valframe[bkgVal], valframe[sigVal]], weightName='gen_weight')

# %%
valframe['ams'] = amsScan(valframe)[0]
# Out:
# [0.91711342334747314, 1.6801446088401104]

# %%
bests = foldAMSScan(valframe, 10)
# Out:
# [0.97490996122360229, 2.491894532637951]
# Fold 0, best AMS 2.49189453264 at cut of 0.974909961224. Total weights Signal:Bkg. 13.6413469315:8097.28320312
# /home/giles/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /home/giles/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
# [0.89839929342269897, 1.4818825338684394]
# Fold 1, best AMS 1.48188253387 at cut of 0.898399293423. Total weights Signal:Bkg. 14.4866523743:8236.44726562
# [0.91829603910446167, 1.760668214068805]
# Fold 2, best AMS 1.76066821407 at cut of 0.918296039104. Total weights Signal:Bkg. 13.8697214127:8156.33203125
# [0.95171064138412476, 2.1144230938823565]
# Fold 3, best AMS 2.11442309388 at cut of 0.951710641384. Total weights Signal:Bkg. 14.0146961212:8184.08691406
# [0.97913122177124023, 2.902945979520697]
# Fold 4, best AMS 2.90294597952 at cut of 0.979131221771. Total weights Signal:Bkg. 14.0445013046:8162.22802734
# [0.92977499961853027, 1.7135492757876845]
# Fold 5, best AMS 1.71354927579 at cut of 0.929774999619. Total weights Signal:Bkg. 13.4757785797:8167.65332031
# [0.98602044582366943, 1.9494758996052974]
# Fold 6, best AMS 1.94947589961 at cut of 0.986020445824. Total weights Signal:Bkg. 14.1829748154:8208.2578125
# [0.97795403003692627, 2.1285836386925685]
# Fold 7, best AMS 2.12858363869 at cut of 0.977954030037. Total weights Signal:Bkg. 13.7635850906:8167.85742188
# [0.96843576431274414, 2.0275063347174322]
# Fold 8, best AMS 2.02750633472 at cut of 0.968435764313. Total weights Signal:Bkg. 14.0237817764:8225.40039062
# [0.98907142877578735, 1.8360055400089113]
# Fold 9, best AMS 1.83600554001 at cut of 0.989071428776. Total weights Signal:Bkg. 13.4483985901:8186.7421875
# Mean cut 0.953591364134 mean AMS 1.97405295532

# %%
scoreTest(ensemble, weights)
# Out:
# Predicting batch 1 out of 10
# Prediction took 0.000337461038069s per sample
#
# Predicting batch 2 out of 10
# Prediction took 0.000330302815004s per sample
#
# Predicting batch 3 out of 10
# Prediction took 0.000326366164468s per sample
#
# Predicting batch 4 out of 10
# Prediction took 0.00034186947129s per sample
#
# Predicting batch 5 out of 10
# Prediction took 0.00033102236661s per sample
#
# Predicting batch 6 out of 10
# Prediction took 0.000324548565258s per sample
#
# Predicting batch 7 out of 10
# Prediction took 0.000331640694358s per sample
#
# Predicting batch 8 out of 10
# Prediction took 0.000336406070536s per sample
#
# Predicting batch 9 out of 10
# Prediction took 0.000325863621452s per sample
#
# Predicting batch 10 out of 10
# Prediction took 0.000322232710231s per sample

# %%
saveTest(0.953591364134, 'Day_6')
# Out:
# ../Data/Day_6_test.csv

# %%
# !kaggle competitions submit -c higgs-boson -f ../Data/Day_6_test.csv -m"Day_6_pre_bn"
# Out:
# Successfully submitted to Higgs Boson Machine Learning Challenge
