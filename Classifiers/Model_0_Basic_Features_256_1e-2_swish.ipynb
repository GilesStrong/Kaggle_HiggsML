# %% [markdown]
# # First Attempt
# batch size 256 lr 1e-3

# %% [markdown]
# ### Import modules

# %%
# %matplotlib inline
from __future__ import division
import sys
import os
os.environ['MKL_THREADING_LAYER']='GNU'
sys.path.append('../')
from Modules.Basics import *
from Modules.Class_Basics import *
# Out:
# /home/giles/anaconda2/lib/python2.7/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# Using Theano backend.

# %% [markdown]
# ## Options

# %%
classTrainFeatures = basic_features
classModel = 'modelSwish'
varSet = "basic_features"

nSplits = 10
ensembleSize = 10
ensembleMode = 'loss'

maxEpochs = 10000
compileArgs = {'loss':'binary_crossentropy', 'optimizer':'adam'}
trainParams = {'epochs' : 1, 'batch_size' : 256, 'verbose' : 0}
modelParams = {'version':classModel, 'nIn':len(classTrainFeatures), 'compileArgs':compileArgs}

print "\nTraining on", len(classTrainFeatures), "features:", [var for var in classTrainFeatures]
# Out:
# Training on 30 features: ['DER_mass_MMC', 'DER_mass_transverse_met_lep', 'DER_mass_vis', 'PRI_tau_pt', 'DER_deltar_tau_lep', 'PRI_jet_leading_eta', 'PRI_lep_eta', 'PRI_tau_eta', 'DER_lep_eta_centrality', 'DER_mass_jet_jet', 'DER_deltaeta_jet_jet', 'DER_pt_tot', 'DER_met_phi_centrality', 'PRI_jet_num', 'PRI_met', 'DER_pt_h', 'DER_pt_ratio_lep_tau', 'DER_sum_pt', 'PRI_jet_leading_pt', 'PRI_jet_subleading_eta', 'PRI_jet_all_pt', 'PRI_met_sumet', 'DER_prodeta_jet_jet', 'PRI_lep_pt', 'PRI_jet_subleading_pt', 'PRI_met_phi', 'PRI_jet_leading_phi', 'PRI_lep_phi', 'PRI_jet_subleading_phi', 'PRI_tau_phi']

# %% [markdown]
# ## Import data

# %%
trainData = h5py.File(dirLoc + 'train.hdf5', "r+")
valData = h5py.File(dirLoc + 'val.hdf5', "r+")

# %% [markdown]
# ## Determine LR

# %%
lrFinder = batchLRFindClassifier(trainData, nSplits, getClassifier, modelParams, trainParams, lrBounds=[1e-5,0.1], trainOnWeights=False, verbose=0)
# Out:
# 2 classes found, running in binary mode
#
#
# ______________________________________
# Training finished
# Cross-validation took 2.958s
# ______________________________________

# %%
compileArgs['lr'] = 1e-2

# %% [markdown]
# ## Train classifier

# %%
results, histories = batchTrainClassifier(trainData, nSplits, getClassifier, modelParams, trainParams, useCosAnneal=True, trainOnWeights=False, maxEpochs=maxEpochs, verbose=1)
# Out:
# Using cosine annealing
# Running fold 1 / 10
# 2 classes found, running in binary mode
#
# 1 New best found: 0.407899521
# 2 New best found: 0.39163224816
# 3 New best found: 0.384878012572
# 4 New best found: 0.382828628206
# 5 New best found: 0.376154369454
# 7 New best found: 0.372468076968
# 9 New best found: 0.371638542876
# 10 New best found: 0.370013311157
# 15 New best found: 0.368872881333
# 18 New best found: 0.368632955948
# 19 New best found: 0.367406883998
# 22 New best found: 0.367401760877
# 23 New best found: 0.36709332873
# 28 New best found: 0.366004018428
# Early stopping after 38 epochs
# Score is: {'loss': 0.36600401842838698, 'AUC': 0.094935563742238771, 'wAUC': 0.070794721347694489}
# Fold took 35.276s
#
# Running fold 2 / 10
# 1 New best found: 0.404375299829
# 2 New best found: 0.392393506774
# 3 New best found: 0.380883226723
# 4 New best found: 0.377626905793
# 5 New best found: 0.377515619528
# 6 New best found: 0.375315257615
# 7 New best found: 0.375191801147
# 8 New best found: 0.37325081783
# 9 New best found: 0.373189685604
# 11 New best found: 0.372035812026
# 12 New best found: 0.370203106084
# 16 New best found: 0.369997444511
# 23 New best found: 0.369082441092
# 24 New best found: 0.368970756418
# 25 New best found: 0.367847069744
# 33 New best found: 0.367388558088
# 34 New best found: 0.366954327166
# Early stopping after 44 epochs
# Score is: {'loss': 0.36695432716613413, 'AUC': 0.095869547767471586, 'wAUC': 0.070291937482671374}
# Fold took 39.306s
#
# Running fold 3 / 10
# 1 New best found: 0.40107026328
# 2 New best found: 0.383792373589
# 3 New best found: 0.380251030119
# 4 New best found: 0.379065850021
# 5 New best found: 0.378007429894
# 7 New best found: 0.374540890414
# 8 New best found: 0.371798820996
# 13 New best found: 0.371538907234
# 14 New best found: 0.371027798214
# 15 New best found: 0.370196777489
# 20 New best found: 0.368415916
# Early stopping after 30 epochs
# Score is: {'loss': 0.36841591600036949, 'AUC': 0.096154078512405983, 'wAUC': 0.071180899909538242}
# Fold took 27.844s
#
# Running fold 4 / 10
# 1 New best found: 0.396910568312
# 2 New best found: 0.382990396424
# 19 New best found: 0.370752934024
# 20 New best found: 0.37044813939
# 21 New best found: 0.368482412743
# Early stopping after 31 epochs
# Score is: {'loss': 0.36848241274328175, 'AUC': 0.096763877590364866, 'wAUC': 0.070892733669272179}
# Fold took 29.006s
#
# Running fold 9 / 10
# 1 New best found: 0.39993372269
# 2 New best found: 0.388383501576
# 3 New best found: 0.383986490284
# 4 New best found: 0.380008811812
# 5 New best found: 0.379441751478
# 6 New best found: 0.376389192177
# 8 New best found: 0.373200029472
# 15 New best found: 0.372306097979
# 16 New best found: 0.371413592626
# 19 New best found: 0.371076132709
# 22 New best found: 0.370306474042
# 23 New best found: 0.3700904993
# 24 New best found: 0.369232706463
# 29 New best found: 0.368483849254
# Early stopping after 39 epochs
# Score is: {'loss': 0.36848384925372002, 'AUC': 0.096374758865466759, 'wAUC': 0.072052700906551581}
# Fold took 36.491s
#
# Running fold 10 / 10
# 1 New best found: 0.402373086755
# 2 New best found: 0.393292811793
# 3 New best found: 0.38985206114
# 4 New best found: 0.38620243376
# 6 New best found: 0.382029490572
# 9 New best found: 0.380297197655
# 11 New best found: 0.37929863174
# 12 New best found: 0.3782698989
# 14 New best found: 0.378231663132
# 16 New best found: 0.376893923535
# 19 New best found: 0.376733306659
# 20 New best found: 0.376202736534
# 22 New best found: 0.375005634859
# 26 New best found: 0.374705690642
# 35 New best found: 0.374697545874
# 40 New best found: 0.374381754318
# 41 New best found: 0.373767094318
# 47 New best found: 0.373222787651
# Early stopping after 57 epochs
# Score is: {'loss': 0.37322278765059519, 'AUC': 0.099562519963564577, 'wAUC': 0.073695791878686245}
# Fold took 51.493s
#
#
# ______________________________________
# Training finished
# Cross-validation took 379.695s
# Mean wAUC = 0.0716 +- 0.0006
# ______________________________________

# %% [markdown]
# ## Construct ensemble

# %%
with open('train_weights/resultsFile.pkl', 'r') as fin:   
    results = pickle.load(fin)

# %%
ensemble, weights = assembleEnsemble(results, ensembleSize, ensembleMode, compileArgs)

# %% [markdown]
# ## Response on development data

# %%
batchEnsemblePredict(ensemble, weights, trainData, ensembleSize=10, verbose=1)

# %%
print 'Training ROC AUC: unweighted {}, weighted {}'.format(roc_auc_score(getFeature('targets', trainData), getFeature('pred', trainData)),
                                                            roc_auc_score(getFeature('targets', trainData), getFeature('pred', trainData), sample_weight=getFeature('weights', trainData)))

# %% [markdown]
# ## Response on val data

# %%
batchEnsemblePredict(ensemble, weights, testData, ensembleSize=10, verbose=1)

# %%
print 'Testing ROC AUC: unweighted {}, weighted {}'.format(roc_auc_score(getFeature('targets', testData), getFeature('pred', testData)),
                                                           roc_auc_score(getFeature('targets', testData), getFeature('pred', testData), sample_weight=getFeature('weights', testData)))

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ### Import in dataframe

# %%
def convertToDF(datafile, columns={'gen_target', 'gen_weight', 'gen_sample', 'pred_class'}, nLoad=-1):
    data = pandas.DataFrame()
    data['gen_target'] = getFeature('targets', datafile, nLoad)
    data['gen_weight'] = getFeature('weights', datafile, nLoad)
    data['gen_sample'] = getFeature('gen_sample', datafile, nLoad)
    data['pred_class'] = getFeature('pred', datafile, nLoad)
    print len(data), "candidates loaded"
    return data

# %%
devData = convertToDF(trainData)
valData = convertToDF(testData)

# %%
sigVal = (valData.gen_target == 1)
bkgVal = (valData.gen_target == 0)

# %% [markdown]
# ### ROC curve

# %%
rocPlot(inData=[devData, valData],
        params=[{'linestyle':'dashed', 'color':'b'}, {'color':'b'}],
        labels=['Train', 'Test'], weightName='gen_weight')

# %% [markdown]
# ### MVA distributions

# %%
getClassPredPlot([valData[bkgVal], valData[sigVal]], weightName='gen_weight')

# %%
getSamplePredPlot(valData)

# %% [markdown]
# ## Save classified data

# %%
name = dirLoc + signal + "_" + channel + "_" + varSet + '_' + classModel + '_classifiedData.csv'
print "Saving data to", name
valData.to_csv(name, columns=['gen_target', 'gen_weight', 'gen_sample', 'pred_class'])

# %% [markdown]
# ## Save/load

# %%
name = "weights/DNN_" + signal + "_" + channel + "_" + varSet + '_' + classModel
print name

# %% [markdown]
# ### Save

# %%
saveEnsemble(name, ensemble, weights, compileArgs, overwrite=1)

# %% [markdown]
# ### Load

# %%
ensemble, weights, compileArgs, inputPipe, outputPipe = loadEnsemble(name)
