# %% [markdown]
# # First Attempt
# batch size 256 lr 1e-3

# %% [markdown]
# ### Import modules

# %%
# %matplotlib inline
from __future__ import division
import sys
import os
os.environ['MKL_THREADING_LAYER']='GNU'
sys.path.append('../')
from Modules.Basics import *
from Modules.Class_Basics import *
# Out:
# /home/giles/anaconda2/lib/python2.7/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# Using Theano backend.

# %% [markdown]
# ## Options

# %%
classTrainFeatures = basic_features
classModel = 'modelSwish'
varSet = "basic_features"

nSplits = 10
ensembleSize = 10
ensembleMode = 'loss'

maxEpochs = 10000
compileArgs = {'loss':'binary_crossentropy', 'optimizer':'adam'}
trainParams = {'epochs' : 1, 'batch_size' : 256, 'verbose' : 0}
modelParams = {'version':classModel, 'nIn':len(classTrainFeatures), 'compileArgs':compileArgs}

print "\nTraining on", len(classTrainFeatures), "features:", [var for var in classTrainFeatures]
# Out:
# Training on 30 features: ['DER_mass_MMC', 'DER_mass_transverse_met_lep', 'DER_mass_vis', 'PRI_tau_pt', 'DER_deltar_tau_lep', 'PRI_jet_leading_eta', 'PRI_lep_eta', 'PRI_tau_eta', 'DER_lep_eta_centrality', 'DER_mass_jet_jet', 'DER_deltaeta_jet_jet', 'DER_pt_tot', 'DER_met_phi_centrality', 'PRI_jet_num', 'PRI_met', 'DER_pt_h', 'DER_pt_ratio_lep_tau', 'DER_sum_pt', 'PRI_jet_leading_pt', 'PRI_jet_subleading_eta', 'PRI_jet_all_pt', 'PRI_met_sumet', 'DER_prodeta_jet_jet', 'PRI_lep_pt', 'PRI_jet_subleading_pt', 'PRI_met_phi', 'PRI_jet_leading_phi', 'PRI_lep_phi', 'PRI_jet_subleading_phi', 'PRI_tau_phi']

# %% [markdown]
# ## Import data

# %%
trainData = h5py.File(dirLoc + 'train.hdf5', "r+")
valData = h5py.File(dirLoc + 'val.hdf5', "r+")

# %% [markdown]
# ## Determine LR

# %%
lrFinder = batchLRFindClassifier(trainData, nSplits, getClassifier, modelParams, trainParams, lrBounds=[1e-5,0.1], trainOnWeights=False, verbose=0)

# %%
compileArgs['lr'] = 1e-2

# %% [markdown]
# ## Train classifier

# %%
results, histories = batchTrainClassifier(trainData, nSplits, getClassifier, modelParams, trainParams, cosAnnealMult=2, trainOnWeights=False, maxEpochs=maxEpochs, verbose=1)
# Out:
# Using cosine annealing
# Running fold 1 / 10
# 2 classes found, running in binary mode
#
# 1 New best found: 0.39851850825
# 3 New best found: 0.378018053281
# 6 New best found: 0.373818654954
# 7 New best found: 0.368301386255
# 13 New best found: 0.365337164784
# 14 New best found: 0.364040376173
# 15 New best found: 0.363527067458
# Early stopping after 25 epochs
# Score is: {'loss': 0.363527067458213, 'AUC': 0.093804270566494319, 'wAUC': 0.070617054910997235}
# Fold took 30.280s
#
# Running fold 2 / 10
# 1 New best found: 0.40529379754
# 2 New best found: 0.395994098327
# 3 New best found: 0.378085678487
# 6 New best found: 0.37376587987
# 7 New best found: 0.369481371633
# 13 New best found: 0.368972632719
# 14 New best found: 0.36600236682
# 15 New best found: 0.365388717888
# Early stopping after 25 epochs
# Score is: {'loss': 0.36538871788790478, 'AUC': 0.094921981871856742, 'wAUC': 0.07021224619373001}
# Fold took 24.919s
#
# Running fold 3 / 10
# 1 New best found: 0.407930535074
# 2 New best found: 0.397183059487
# 3 New best found: 0.379667234147
# 7 New best found: 0.37173243748
# 12 New best found: 0.371262364073
# 13 New best found: 0.368646796982
# 14 New best found: 0.367015012934
# 15 New best found: 0.366189786951
# Early stopping after 25 epochs
# Score is: {'loss': 0.36618978695074844, 'AUC': 0.095262439271937116, 'wAUC': 0.070965118166424146}
# Fold took 25.309s
#
# Running fold 4 / 10
# 1 New best found: 0.402043797415
# 2 New best found: 0.3911347678
# 3 New best found: 0.374789219874
# 6 New best found: 0.371703747823
# 7 New best found: 0.367902034113
# 14 New best found: 0.365320934237
# 15 New best found: 0.365131450985
# Early stopping after 25 epochs
# Score is: {'loss': 0.36513145098492722, 'AUC': 0.094998188798216643, 'wAUC': 0.073888106341415849}
# Fold took 23.643s
#
# Running fold 5 / 10
# 1 New best found: 0.404369790238
# 2 New best found: 0.396947590036
# 3 New best found: 0.375720972316
# 6 New best found: 0.370895180505
# 7 New best found: 0.367966471869
# 13 New best found: 0.366253638436
# 14 New best found: 0.363073146898
# 15 New best found: 0.362705595572
# Early stopping after 25 epochs
# Score is: {'loss': 0.36270559557165327, 'AUC': 0.093248226692627334, 'wAUC': 0.069425825416159714}
# Fold took 25.352s
#
# Running fold 6 / 10
# 1 New best found: 0.394339801659
# 3 New best found: 0.371663948569
# 6 New best found: 0.365192800639
# 7 New best found: 0.36230009824
# 13 New best found: 0.360485756528
# 14 New best found: 0.358184966567
# 15 New best found: 0.357826648947
# Early stopping after 25 epochs
# Score is: {'loss': 0.35782664894714583, 'AUC': 0.090869619415727798, 'wAUC': 0.066666872551052525}
# Fold took 24.688s
#
# Running fold 7 / 10
# 1 New best found: 0.410258326115
# 2 New best found: 0.396806870831
# 3 New best found: 0.380550094793
# 6 New best found: 0.372765439886
# 7 New best found: 0.370519326637
# 13 New best found: 0.366799752371
# 14 New best found: 0.36445670321
# 15 New best found: 0.363997039729
# Early stopping after 25 epochs
# Score is: {'loss': 0.36399703972898007, 'AUC': 0.093964211150321608, 'wAUC': 0.072638378329761055}
# Fold took 23.862s
#
# Running fold 8 / 10
# 1 New best found: 0.403562717835
# 2 New best found: 0.398264964047
# 3 New best found: 0.378740124668
# 6 New best found: 0.373031764154
# 7 New best found: 0.370761917331
# 13 New best found: 0.368188548455
# 14 New best found: 0.36780143481
# 15 New best found: 0.366309032868
# Early stopping after 25 epochs
# Score is: {'loss': 0.36630903286826277, 'AUC': 0.09559345565197308, 'wAUC': 0.070605063153765135}
# Fold took 23.955s
#
# Running fold 9 / 10
# 1 New best found: 0.400641790187
# 2 New best found: 0.393044405709
# 3 New best found: 0.379479981718
# 6 New best found: 0.374119653031
# 7 New best found: 0.371114116402
# 13 New best found: 0.370057012288
# 14 New best found: 0.366802245175
# 15 New best found: 0.366379871794
# Early stopping after 25 epochs
# Score is: {'loss': 0.36637987179436349, 'AUC': 0.095458073304364954, 'wAUC': 0.070397857164617883}
# Fold took 25.235s
#
# Running fold 10 / 10
# 1 New best found: 0.41091095774
# 2 New best found: 0.404786070704
# 3 New best found: 0.387222553388
# 6 New best found: 0.380215494996
# 7 New best found: 0.378199626875
# 13 New best found: 0.376696263911
# 14 New best found: 0.374662383437
# 15 New best found: 0.373954736899
# Early stopping after 25 epochs
# Score is: {'loss': 0.37395473689879499, 'AUC': 0.10033358174905549, 'wAUC': 0.073814231784432804}
# Fold took 26.050s
#
#
# ______________________________________
# Training finished
# Cross-validation took 253.569s
# Mean wAUC = 0.0709 +- 0.0006
# ______________________________________

# %% [markdown]
# ## Construct ensemble

# %%
with open('train_weights/resultsFile.pkl', 'r') as fin:   
    results = pickle.load(fin)

# %%
ensemble, weights = assembleEnsemble(results, ensembleSize, ensembleMode, compileArgs)

# %% [markdown]
# ## Response on development data

# %%
batchEnsemblePredict(ensemble, weights, trainData, ensembleSize=10, verbose=1)

# %%
print 'Training ROC AUC: unweighted {}, weighted {}'.format(roc_auc_score(getFeature('targets', trainData), getFeature('pred', trainData)),
                                                            roc_auc_score(getFeature('targets', trainData), getFeature('pred', trainData), sample_weight=getFeature('weights', trainData)))

# %% [markdown]
# ## Response on val data

# %%
batchEnsemblePredict(ensemble, weights, testData, ensembleSize=10, verbose=1)

# %%
print 'Testing ROC AUC: unweighted {}, weighted {}'.format(roc_auc_score(getFeature('targets', testData), getFeature('pred', testData)),
                                                           roc_auc_score(getFeature('targets', testData), getFeature('pred', testData), sample_weight=getFeature('weights', testData)))

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ### Import in dataframe

# %%
def convertToDF(datafile, columns={'gen_target', 'gen_weight', 'gen_sample', 'pred_class'}, nLoad=-1):
    data = pandas.DataFrame()
    data['gen_target'] = getFeature('targets', datafile, nLoad)
    data['gen_weight'] = getFeature('weights', datafile, nLoad)
    data['gen_sample'] = getFeature('gen_sample', datafile, nLoad)
    data['pred_class'] = getFeature('pred', datafile, nLoad)
    print len(data), "candidates loaded"
    return data

# %%
devData = convertToDF(trainData)
valData = convertToDF(testData)

# %%
sigVal = (valData.gen_target == 1)
bkgVal = (valData.gen_target == 0)

# %% [markdown]
# ### ROC curve

# %%
rocPlot(inData=[devData, valData],
        params=[{'linestyle':'dashed', 'color':'b'}, {'color':'b'}],
        labels=['Train', 'Test'], weightName='gen_weight')

# %% [markdown]
# ### MVA distributions

# %%
getClassPredPlot([valData[bkgVal], valData[sigVal]], weightName='gen_weight')

# %%
getSamplePredPlot(valData)

# %% [markdown]
# ## Save classified data

# %%
name = dirLoc + signal + "_" + channel + "_" + varSet + '_' + classModel + '_classifiedData.csv'
print "Saving data to", name
valData.to_csv(name, columns=['gen_target', 'gen_weight', 'gen_sample', 'pred_class'])

# %% [markdown]
# ## Save/load

# %%
name = "weights/DNN_" + signal + "_" + channel + "_" + varSet + '_' + classModel
print name

# %% [markdown]
# ### Save

# %%
saveEnsemble(name, ensemble, weights, compileArgs, overwrite=1)

# %% [markdown]
# ### Load

# %%
ensemble, weights, compileArgs, inputPipe, outputPipe = loadEnsemble(name)
