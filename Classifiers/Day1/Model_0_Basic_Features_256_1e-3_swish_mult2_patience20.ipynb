# %% [markdown]
# # First Attempt
# batch size 256 lr 1e-3

# %% [markdown]
# ### Import modules

# %%
# %matplotlib inline
from __future__ import division
import sys
import os
os.environ['MKL_THREADING_LAYER']='GNU'
sys.path.append('../')
from Modules.Basics import *
from Modules.Class_Basics import *
# Out:
# /home/giles/anaconda2/lib/python2.7/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# Using Theano backend.
# /home/giles/anaconda2/lib/python2.7/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# ## Options

# %%
classTrainFeatures = basic_features
classModel = 'modelSwish'
varSet = "basic_features"

nSplits = 10
ensembleSize = 10
ensembleMode = 'loss'

maxEpochs = 10000
compileArgs = {'loss':'binary_crossentropy', 'optimizer':'adam'}
trainParams = {'epochs' : 1, 'batch_size' : 256, 'verbose' : 0}
modelParams = {'version':classModel, 'nIn':len(classTrainFeatures), 'compileArgs':compileArgs}

print "\nTraining on", len(classTrainFeatures), "features:", [var for var in classTrainFeatures]
# Out:
# Training on 30 features: ['DER_mass_MMC', 'DER_mass_transverse_met_lep', 'DER_mass_vis', 'PRI_tau_pt', 'DER_deltar_tau_lep', 'PRI_jet_leading_eta', 'PRI_lep_eta', 'PRI_tau_eta', 'DER_lep_eta_centrality', 'DER_mass_jet_jet', 'DER_deltaeta_jet_jet', 'DER_pt_tot', 'DER_met_phi_centrality', 'PRI_jet_num', 'PRI_met', 'DER_pt_h', 'DER_pt_ratio_lep_tau', 'DER_sum_pt', 'PRI_jet_leading_pt', 'PRI_jet_subleading_eta', 'PRI_jet_all_pt', 'PRI_met_sumet', 'DER_prodeta_jet_jet', 'PRI_lep_pt', 'PRI_jet_subleading_pt', 'PRI_met_phi', 'PRI_jet_leading_phi', 'PRI_lep_phi', 'PRI_jet_subleading_phi', 'PRI_tau_phi']

# %% [markdown]
# ## Import data

# %%
trainData = h5py.File(dirLoc + 'train.hdf5', "r+")
valData = h5py.File(dirLoc + 'val.hdf5', "r+")

# %% [markdown]
# ## Determine LR

# %%
lrFinder = batchLRFindClassifier(trainData, nSplits, getClassifier, modelParams, trainParams, lrBounds=[1e-5,1e-2], trainOnWeights=False, verbose=0)
# Out:
# 2 classes found, running in binary mode
#
#
# ______________________________________
# Training finished
# Cross-validation took 7.015s
# ______________________________________

# %%
compileArgs['lr'] = 1e-3

# %% [markdown]
# ## Train classifier

# %%
results, histories = batchTrainClassifier(trainData, nSplits, getClassifier, modelParams, trainParams, patience=20, cosAnnealMult=2, trainOnWeights=False, maxEpochs=maxEpochs, verbose=1)
# Out:
# Using cosine annealing
# Running fold 1 / 10
# 2 classes found, running in binary mode
#
# 1 New best found: 0.477722981245
# 2 New best found: 0.425479322025
# 3 New best found: 0.416361851766
# 4 New best found: 0.404430264375
# 5 New best found: 0.397690167733
# 6 New best found: 0.390346106636
# 7 New best found: 0.389764624643
# 8 New best found: 0.387458669837
# 10 New best found: 0.38286427605
# 11 New best found: 0.381832220156
# 12 New best found: 0.375810327992
# 13 New best found: 0.37482418295
# 14 New best found: 0.37433891955
# 15 New best found: 0.373796481228
# 22 New best found: 0.373610033722
# 23 New best found: 0.369329546557
# 24 New best found: 0.369071914262
# 25 New best found: 0.367742270274
# 26 New best found: 0.366988180403
# 28 New best found: 0.366010698365
# 29 New best found: 0.365516089415
# 30 New best found: 0.365214297064
# 31 New best found: 0.365182626903
# 45 New best found: 0.364935105826
# 46 New best found: 0.364221013728
# 47 New best found: 0.363843842974
# 48 New best found: 0.362983148775
# 49 New best found: 0.362164314394
# 50 New best found: 0.361613491415
# 52 New best found: 0.361558291699
# 53 New best found: 0.36146934083
# 54 New best found: 0.36139350573
# 55 New best found: 0.360938318363
# 56 New best found: 0.360844681543
# 57 New best found: 0.360274165219
# 59 New best found: 0.360223655178
# 61 New best found: 0.360189148703
# 62 New best found: 0.360132110338
# 63 New best found: 0.360130424731
# Early stopping after 83 epochs
# Score is: {'loss': 0.36013042473107909, 'AUC': 0.091932043605733149, 'wAUC': 0.069320569531373888}
# Fold took 65.925s
#
# Running fold 2 / 10
# 1 New best found: 0.472808108415
# 2 New best found: 0.420232999916
# 3 New best found: 0.411173953744
# 4 New best found: 0.403120781777
# 5 New best found: 0.401588131598
# 6 New best found: 0.38589938816
# 7 New best found: 0.38423024516
# 9 New best found: 0.38413893995
# 10 New best found: 0.380235954807
# 11 New best found: 0.379237249278
# 12 New best found: 0.374815738576
# 13 New best found: 0.373012995521
# 14 New best found: 0.372835579976
# 15 New best found: 0.372478386039
# 23 New best found: 0.37007373535
# 24 New best found: 0.369130510565
# 26 New best found: 0.368744039952
# 27 New best found: 0.367733013177
# 28 New best found: 0.367169535901
# 29 New best found: 0.36663966376
# 30 New best found: 0.366359275865
# 31 New best found: 0.366351318864
# 45 New best found: 0.36619115474
# 47 New best found: 0.3661864811
# 49 New best found: 0.364417592425
# 55 New best found: 0.364177674775
# 56 New best found: 0.363889970711
# 57 New best found: 0.363828074387
# 58 New best found: 0.363329064326
# 59 New best found: 0.363106729354
# 60 New best found: 0.363001572657
# 61 New best found: 0.362878153633
# 62 New best found: 0.362862290981
# Early stopping after 82 epochs
# Score is: {'loss': 0.36286229098149669, 'AUC': 0.093674526501349664, 'wAUC': 0.069684287630701669}
# Fold took 62.070s
#
# Running fold 3 / 10
# 1 New best found: 0.468757507044
# 2 New best found: 0.418968568229
# 3 New best found: 0.408806047424
# 4 New best found: 0.39579142661
# 5 New best found: 0.388656585385
# 6 New best found: 0.382883947358
# 7 New best found: 0.382057773752
# 9 New best found: 0.381385923004
# 10 New best found: 0.378035072624
# 11 New best found: 0.377591662011
# 12 New best found: 0.375962675455
# 13 New best found: 0.373569751399
# 15 New best found: 0.373511239032
# 18 New best found: 0.372133894102
# 19 New best found: 0.371928792707
# 23 New best found: 0.371528254045
# 24 New best found: 0.368889182846
# 26 New best found: 0.367446242651
# 28 New best found: 0.367127942131
# 29 New best found: 0.366757521289
# 43 New best found: 0.366710692517
# 45 New best found: 0.365533607959
# 49 New best found: 0.365394944537
# 51 New best found: 0.364769591432
# 52 New best found: 0.363803278428
# 56 New best found: 0.363697655958
# 57 New best found: 0.363398843715
# 59 New best found: 0.363293828133
# 60 New best found: 0.363291876661
# 61 New best found: 0.363139378226
# 62 New best found: 0.363068234258
# 63 New best found: 0.363063051798
# Early stopping after 83 epochs
# Score is: {'loss': 0.36306305179821957, 'AUC': 0.093618705347241149, 'wAUC': 0.069079491831903983}
# Fold took 64.479s
#
# Running fold 4 / 10
# 1 New best found: 0.474627927065
# 2 New best found: 0.419441829085
# 3 New best found: 0.409774523067
# 4 New best found: 0.399534384584
# 5 New best found: 0.391580389428
# 6 New best found: 0.385120960021
# 7 New best found: 0.384508891082
# 9 New best found: 0.382879331732
# 10 New best found: 0.379550375986
# 11 New best found: 0.37606899364
# 12 New best found: 0.374512275124
# 13 New best found: 0.372266463232
# 14 New best found: 0.371725212979
# 15 New best found: 0.371686800027
# 19 New best found: 0.3711907547
# 22 New best found: 0.368838947868
# 25 New best found: 0.368613435996
# 26 New best found: 0.368402608299
# 27 New best found: 0.366466724515
# 28 New best found: 0.365849724388
# 29 New best found: 0.365711682403
# 30 New best found: 0.365625109649
# 31 New best found: 0.365551185274
# 46 New best found: 0.363766648293
# 50 New best found: 0.363744434118
# 52 New best found: 0.363516553855
# 53 New best found: 0.362434779739
# 54 New best found: 0.362419687009
# 55 New best found: 0.362325720143
# 56 New best found: 0.361954983366
# 58 New best found: 0.361546852136
# Early stopping after 78 epochs
# Score is: {'loss': 0.36154685213565824, 'AUC': 0.093093239441675468, 'wAUC': 0.073182663576893181}
# Fold took 61.095s
#
# Running fold 5 / 10
# 1 New best found: 0.478065425014
# 2 New best found: 0.425765497565
# 3 New best found: 0.416545520854
# 4 New best found: 0.400843556452
# 5 New best found: 0.39169308579
# 6 New best found: 0.386520520949
# 7 New best found: 0.385428237772
# 9 New best found: 0.383639550018
# 10 New best found: 0.382884559512
# 12 New best found: 0.376397971654
# 13 New best found: 0.374470110488
# 14 New best found: 0.373137466526
# 15 New best found: 0.372636488509
# 19 New best found: 0.372326204157
# 21 New best found: 0.371433942413
# 22 New best found: 0.370408104181
# 23 New best found: 0.367086727428
# 26 New best found: 0.366328151011
# 27 New best found: 0.3653616781
# 28 New best found: 0.365061770797
# 29 New best found: 0.364957691908
# 30 New best found: 0.364826253247
# 31 New best found: 0.364788441253
# 41 New best found: 0.363903411245
# 46 New best found: 0.363480368853
# 47 New best found: 0.362533434677
# 53 New best found: 0.361797930789
# 54 New best found: 0.361662018085
# 55 New best found: 0.361136619806
# 59 New best found: 0.360933040881
# 61 New best found: 0.360905306268
# 62 New best found: 0.360865643787
# 63 New best found: 0.360855537844
# Early stopping after 83 epochs
# Score is: {'loss': 0.36085553784370422, 'AUC': 0.092394358557357559, 'wAUC': 0.068976796879735458}
# Fold took 64.882s
#
# Running fold 6 / 10
# 1 New best found: 0.463142376828
# 2 New best found: 0.41019494729
# 3 New best found: 0.398424496627
# 4 New best found: 0.384339348316
# 5 New best found: 0.379740034676
# 6 New best found: 0.374909688163
# 7 New best found: 0.37365816381
# 9 New best found: 0.369297848344
# 11 New best found: 0.368017089844
# 12 New best found: 0.365607146013
# 13 New best found: 0.364462925911
# 14 New best found: 0.36393669126
# 15 New best found: 0.363624417233
# 24 New best found: 0.360766876566
# 25 New best found: 0.360277245665
# 26 New best found: 0.360053238535
# 27 New best found: 0.359869106698
# 28 New best found: 0.359675856471
# 29 New best found: 0.358621071243
# 31 New best found: 0.358529163408
# 48 New best found: 0.358162395501
# 49 New best found: 0.356825577068
# 52 New best found: 0.356677669215
# 53 New best found: 0.356303278089
# 54 New best found: 0.356220725965
# 55 New best found: 0.356180007529
# 56 New best found: 0.35588454051
# 57 New best found: 0.355751280999
# 58 New best found: 0.355331424689
# 61 New best found: 0.355281272864
# 62 New best found: 0.355260104227
# Early stopping after 82 epochs
# Score is: {'loss': 0.35526010422706605, 'AUC': 0.089599928982409427, 'wAUC': 0.066450613797035984}
# Fold took 63.623s
#
# Running fold 7 / 10
# 1 New best found: 0.462959354281
# 2 New best found: 0.422700600028
# 3 New best found: 0.412852585506
# 4 New best found: 0.405724632621
# 5 New best found: 0.399915082097
# 6 New best found: 0.391101265621
# 7 New best found: 0.389499986243
# 9 New best found: 0.386084453177
# 10 New best found: 0.382852667284
# 12 New best found: 0.378421215844
# 13 New best found: 0.377274258065
# 14 New best found: 0.376106570625
# 15 New best found: 0.375907387877
# 19 New best found: 0.375083191895
# 21 New best found: 0.373939184546
# 22 New best found: 0.372143566549
# 25 New best found: 0.371586582458
# 26 New best found: 0.369651070404
# 27 New best found: 0.369433165717
# 28 New best found: 0.369278826916
# 29 New best found: 0.368565419674
# 30 New best found: 0.368266719818
# 31 New best found: 0.368230111861
# 45 New best found: 0.367573056936
# 48 New best found: 0.366835260713
# 49 New best found: 0.366043386793
# 52 New best found: 0.365365929699
# 53 New best found: 0.364540344429
# 56 New best found: 0.364437599277
# 57 New best found: 0.364148542595
# 58 New best found: 0.364112335026
# 60 New best found: 0.364064596367
# 61 New best found: 0.363954734063
# 62 New best found: 0.363932155061
# 63 New best found: 0.363923464632
# Early stopping after 83 epochs
# Score is: {'loss': 0.36392346463203429, 'AUC': 0.09401790415388489, 'wAUC': 0.072914924719845731}
# Fold took 64.129s
#
# Running fold 8 / 10
# 1 New best found: 0.470458434916
# 2 New best found: 0.422380054824
# 3 New best found: 0.4104007213
# 4 New best found: 0.398492709493
# 5 New best found: 0.391170784958
# 6 New best found: 0.386002078668
# 7 New best found: 0.384361927586
# 9 New best found: 0.381306704822
# 10 New best found: 0.375684889174
# 12 New best found: 0.374471488211
# 13 New best found: 0.372869694356
# 14 New best found: 0.371776006759
# 15 New best found: 0.371647880582
# 23 New best found: 0.3695586034
# 24 New best found: 0.36918570073
# 26 New best found: 0.368692358259
# 27 New best found: 0.367396924202
# 28 New best found: 0.367018542565
# 29 New best found: 0.366985675458
# 30 New best found: 0.366692685651
# 31 New best found: 0.366635520678
# 46 New best found: 0.36554991358
# 49 New best found: 0.365341671862
# 50 New best found: 0.364671330125
# 51 New best found: 0.364542453785
# 54 New best found: 0.36419693473
# 55 New best found: 0.363965272947
# 58 New best found: 0.36373360062
# 59 New best found: 0.363607655806
# 60 New best found: 0.363329282781
# Early stopping after 80 epochs
# Score is: {'loss': 0.36332928278105359, 'AUC': 0.094068182673485268, 'wAUC': 0.070077384981347635}
# Fold took 62.418s
#
# Running fold 9 / 10
# 1 New best found: 0.480757108511
# 2 New best found: 0.423682993077
# 3 New best found: 0.414327484693
# 4 New best found: 0.414243395692
# 5 New best found: 0.396424577444
# 6 New best found: 0.391536821563
# 7 New best found: 0.390704582195
# 8 New best found: 0.390695971265
# 9 New best found: 0.390022974918
# 10 New best found: 0.383457782111
# 11 New best found: 0.382064450503
# 12 New best found: 0.37870331552
# 14 New best found: 0.377485451335
# 15 New best found: 0.377096413204
# 21 New best found: 0.376496887929
# 22 New best found: 0.375939834505
# 24 New best found: 0.37282075798
# 25 New best found: 0.372406616821
# 27 New best found: 0.371127927512
# 28 New best found: 0.370632023966
# 29 New best found: 0.370270451535
# 30 New best found: 0.369936664201
# 42 New best found: 0.369784221754
# 43 New best found: 0.368514809057
# 48 New best found: 0.367146112998
# 50 New best found: 0.366844381578
# 52 New best found: 0.365888483856
# 54 New best found: 0.365878984003
# 55 New best found: 0.365273900836
# 57 New best found: 0.365133904332
# 60 New best found: 0.365004255203
# Early stopping after 80 epochs
# Score is: {'loss': 0.36500425520309943, 'AUC': 0.094781117134966508, 'wAUC': 0.070215014790649288}
# Fold took 62.952s
#
# Running fold 10 / 10
# 1 New best found: 0.474285307929
# 2 New best found: 0.425611385076
# 3 New best found: 0.417788585117
# 4 New best found: 0.413141931771
# 5 New best found: 0.396799020226
# 6 New best found: 0.391442059956
# 7 New best found: 0.390487458356
# 9 New best found: 0.390152185678
# 11 New best found: 0.388653269676
# 12 New best found: 0.381275137262
# 13 New best found: 0.380684026489
# 14 New best found: 0.379837709873
# 15 New best found: 0.379207100326
# 21 New best found: 0.379016104086
# 23 New best found: 0.377257143647
# 25 New best found: 0.375472505909
# 26 New best found: 0.374227863145
# 28 New best found: 0.373671325433
# 29 New best found: 0.373517620664
# 30 New best found: 0.373322755943
# 31 New best found: 0.373276653063
# 47 New best found: 0.37300140097
# 50 New best found: 0.372562512381
# 51 New best found: 0.372159187487
# 55 New best found: 0.371349359575
# 56 New best found: 0.370738330253
# 59 New best found: 0.370440939251
# 60 New best found: 0.370351997006
# 62 New best found: 0.370323780099
# 63 New best found: 0.370316339769
# Early stopping after 83 epochs
# Score is: {'loss': 0.37031633976912687, 'AUC': 0.098130114077067065, 'wAUC': 0.072581643380009497}
# Fold took 64.604s
#
#
# ______________________________________
# Training finished
# Cross-validation took 636.384s
# Mean wAUC = 0.0702 +- 0.0006
# ______________________________________

# %% [markdown]
# ## Construct ensemble

# %%
with open('train_weights/resultsFile.pkl', 'r') as fin:   
    results = pickle.load(fin)

# %%
ensemble, weights = assembleEnsemble(results, ensembleSize, ensembleMode, compileArgs)
# Out:
# Choosing ensemble by loss
# Model 0 is 5 with loss = 0.355260104227
# Model 1 is 0 with loss = 0.360130424731
# Model 2 is 4 with loss = 0.360855537844
# Model 3 is 3 with loss = 0.361546852136
# Model 4 is 1 with loss = 0.362862290981
# Model 5 is 2 with loss = 0.363063051798
# Model 6 is 7 with loss = 0.363329282781
# Model 7 is 6 with loss = 0.363923464632
# Model 8 is 8 with loss = 0.365004255203
# Model 9 is 9 with loss = 0.370316339769

# %% [markdown]
# ## Response on development data

# %%
batchEnsemblePredict(ensemble, weights, trainData, ensembleSize=10, verbose=1)
# Out:
# Predicting batch 1 out of 10
# Prediction took 0.000180719316104s per sample
#
# Predicting batch 2 out of 10
# Prediction took 0.00014640698343s per sample
#
# Predicting batch 3 out of 10
# Prediction took 0.000150348036225s per sample
#
# Predicting batch 4 out of 10
# Prediction took 0.000159123897552s per sample
#
# Predicting batch 5 out of 10
# Prediction took 0.000154088652134s per sample
#
# Predicting batch 6 out of 10
# Prediction took 0.000152647197247s per sample
#
# Predicting batch 7 out of 10
# Prediction took 0.000153722643852s per sample
#
# Predicting batch 8 out of 10
# Prediction took 0.000148466726715s per sample
#
# Predicting batch 9 out of 10
# Prediction took 0.000153382674856s per sample
#
# Predicting batch 10 out of 10
# Prediction took 0.000150633630791s per sample

# %%
print 'Training ROC AUC: unweighted {}, weighted {}'.format(roc_auc_score(getFeature('targets', trainData), getFeature('pred', trainData)),
                                                            roc_auc_score(getFeature('targets', trainData), getFeature('pred', trainData), sample_weight=getFeature('weights', trainData)))
# Out:
# Training ROC AUC: unweighted 0.910624443416, weighted 0.932446674923

# %% [markdown]
# ## Response on val data

# %%
batchEnsemblePredict(ensemble, weights, valData, ensembleSize=10, verbose=1)
# Out:
# Predicting batch 1 out of 10
# Prediction took 0.000151235628128s per sample
#
# Predicting batch 2 out of 10
# Prediction took 0.000149731588364s per sample
#
# Predicting batch 3 out of 10
# Prediction took 0.000148037195206s per sample
#
# Predicting batch 4 out of 10
# Prediction took 0.00014841504097s per sample
#
# Predicting batch 5 out of 10
# Prediction took 0.000156605768204s per sample
#
# Predicting batch 6 out of 10
# Prediction took 0.000148265981674s per sample
#
# Predicting batch 7 out of 10
# Prediction took 0.000148189020157s per sample
#
# Predicting batch 8 out of 10
# Prediction took 0.000148903417587s per sample
#
# Predicting batch 9 out of 10
# Prediction took 0.000148982000351s per sample
#
# Predicting batch 10 out of 10
# Prediction took 0.000147972393036s per sample

# %%
print 'Testing ROC AUC: unweighted {}, weighted {}'.format(roc_auc_score(getFeature('targets', valData), getFeature('pred', valData)),
                                                           roc_auc_score(getFeature('targets', valData), getFeature('pred', valData), sample_weight=getFeature('weights', valData)))
# Out:
# Testing ROC AUC: unweighted 0.907750851845, weighted 0.92939084997

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ### Import in dataframe

# %%
def convertToDF(datafile, columns={'gen_target', 'gen_weight', 'pred_class'}, nLoad=-1):
    data = pandas.DataFrame()
    data['gen_target'] = getFeature('targets', datafile, nLoad)
    data['gen_weight'] = getFeature('weights', datafile, nLoad)
    data['pred_class'] = getFeature('pred', datafile, nLoad)
    print len(data), "candidates loaded"
    return data

# %%
devData = convertToDF(trainData)
valData = convertToDF(valData)
# Out:
# 200000 candidates loaded
# 50000 candidates loaded

# %%
sigVal = (valData.gen_target == 1)
bkgVal = (valData.gen_target == 0)

# %% [markdown]
# ### MVA distributions

# %%
getClassPredPlot([valData[bkgVal], valData[sigVal]], weightName='gen_weight')

# %%
def AMS(s, b):
    """ Approximate Median Significance defined as:
        AMS = sqrt(
                2 { (s + b + b_r) log[1 + (s/(b+b_r))] - s}
              )        
    where b_r = 10, b = background, s = signal, log is natural logarithm """
    
    br = 10.0
    radicand = 2 *( (s+b+br) * math.log (1.0 + s/(b+br)) -s)
    if radicand < 0:
        print 'radicand is negative. Exiting'
        exit()
    else:
        return math.sqrt(radicand)
    
def amsScan(inData, res=0.0001):
    best = [0,-1]
    for i in np.linspace(0.,1.,1./res):
        ams = AMS(np.sum(inData.loc[(inData['pred_class'] >= i) & sigVal, 'gen_weight']),
                  np.sum(inData.loc[(inData['pred_class'] >= i) & bkgVal, 'gen_weight']))
        if ams > best[1]:
            best = [i, ams]
    print best

# %%
amsScan(valData)
# Out:
# /home/giles/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:18: DeprecationWarning: object of type <type 'float'> cannot be safely interpreted as an integer.
# [0.82258225822582265, 1.5926230941900177]

# %% [markdown]
# ## Save classified data

# %%
name = dirLoc + signal + "_" + channel + "_" + varSet + '_' + classModel + '_classifiedData.csv'
print "Saving data to", name
valData.to_csv(name, columns=['gen_target', 'gen_weight', 'gen_sample', 'pred_class'])

# %% [markdown]
# ## Save/load

# %%
name = "weights/DNN_" + signal + "_" + channel + "_" + varSet + '_' + classModel
print name

# %% [markdown]
# ### Save

# %%
saveEnsemble(name, ensemble, weights, compileArgs, overwrite=1)

# %% [markdown]
# ### Load

# %%
ensemble, weights, compileArgs, inputPipe, outputPipe = loadEnsemble(name)
