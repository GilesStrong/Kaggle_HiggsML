# %% [markdown]
# # First Attempt
# batch size 64 lr 1e-4

# %% [markdown]
# ### Import modules

# %%
# %matplotlib inline
from __future__ import division
import sys
import os
os.environ['MKL_THREADING_LAYER']='GNU'
sys.path.append('../')
from Modules.Basics import *
from Modules.Class_Basics import *

# %% [markdown]
# ## Options

# %%
classTrainFeatures = basic_features
classModel = 'modelSelu'
varSet = "basic_features"

nSplits = 10
ensembleSize = 10
ensembleMode = 'loss'

maxEpochs = 10000
compileArgs = {'loss':'binary_crossentropy', 'optimizer':'adam'}
trainParams = {'epochs' : 1, 'batch_size' : 64, 'verbose' : 0}
modelParams = {'version':classModel, 'nIn':len(classTrainFeatures), 'compileArgs':compileArgs}

print "\nTraining on", len(classTrainFeatures), "features:", [var for var in classTrainFeatures]
# Out:
# Training on 30 features: ['DER_mass_MMC', 'DER_mass_transverse_met_lep', 'DER_mass_vis', 'PRI_tau_pt', 'DER_deltar_tau_lep', 'PRI_jet_leading_eta', 'PRI_lep_eta', 'PRI_tau_eta', 'DER_lep_eta_centrality', 'DER_mass_jet_jet', 'DER_deltaeta_jet_jet', 'DER_pt_tot', 'DER_met_phi_centrality', 'PRI_jet_num', 'PRI_met', 'DER_pt_h', 'DER_pt_ratio_lep_tau', 'DER_sum_pt', 'PRI_jet_leading_pt', 'PRI_jet_subleading_eta', 'PRI_jet_all_pt', 'PRI_met_sumet', 'DER_prodeta_jet_jet', 'PRI_lep_pt', 'PRI_jet_subleading_pt', 'PRI_met_phi', 'PRI_jet_leading_phi', 'PRI_lep_phi', 'PRI_jet_subleading_phi', 'PRI_tau_phi']

# %% [markdown]
# ## Import data

# %%
trainData = h5py.File(dirLoc + 'train.hdf5', "r+")
valData = h5py.File(dirLoc + 'val.hdf5', "r+")

# %% [markdown]
# ## Determine LR

# %%
lrFinder = batchLRFindClassifier(trainData, nSplits, getClassifier, modelParams, trainParams, lrBounds=[1e-5,1e-2], trainOnWeights=False, verbose=0)
# Out:
# 2 classes found, running in binary mode
#
#
# ______________________________________
# Training finished
# Cross-validation took 3.895s
# ______________________________________

# %%
compileArgs['lr'] = 1e-4

# %% [markdown]
# ## Train classifier

# %%
results, histories = batchTrainClassifier(trainData, nSplits, getClassifier, modelParams, trainParams, useCosAnneal=True, trainOnWeights=False, maxEpochs=maxEpochs, verbose=1)
# Out:
# Using cosine annealing
# Running fold 1 / 10
# 2 classes found, running in binary mode
#
# 1 New best found: 0.50339227914
# 2 New best found: 0.478300533308
# 3 New best found: 0.464107503056
# 4 New best found: 0.457160628927
# 5 New best found: 0.447626405171
# 6 New best found: 0.43875244279
# 7 New best found: 0.431959644112
# 8 New best found: 0.424367486345
# 9 New best found: 0.418062328223
# 10 New best found: 0.413371117767
# 11 New best found: 0.409895851456
# 12 New best found: 0.407116059547
# 13 New best found: 0.405308362455
# 14 New best found: 0.403267531407
# 15 New best found: 0.401144198532
# 16 New best found: 0.399284970124
# 17 New best found: 0.398537837514
# 18 New best found: 0.39727501444
# 19 New best found: 0.395266570295
# 20 New best found: 0.394258278977
# 21 New best found: 0.393278391824
# 22 New best found: 0.392282251198
# 23 New best found: 0.391234856412
# 24 New best found: 0.39020990857
# 25 New best found: 0.38963990764
# 26 New best found: 0.389279831209
# 27 New best found: 0.389015479906
# 28 New best found: 0.387309739145
# 29 New best found: 0.38668205692
# 30 New best found: 0.386273160917
# 31 New best found: 0.38585171976
# 32 New best found: 0.385221150564
# 33 New best found: 0.383862160496
# 34 New best found: 0.383643232502
# 35 New best found: 0.383028253533
# 36 New best found: 0.382904756629
# 37 New best found: 0.381840805446
# 38 New best found: 0.381785571432
# 39 New best found: 0.381708863466
# 40 New best found: 0.38106600478
# 41 New best found: 0.38089807194
# 42 New best found: 0.379878998391
# 44 New best found: 0.379035557911
# 46 New best found: 0.378647271978
# 47 New best found: 0.378518138386
# 48 New best found: 0.377929828717
# 51 New best found: 0.376625264042
# 54 New best found: 0.376563890151
# 55 New best found: 0.375823242265
# 56 New best found: 0.375670407298
# 57 New best found: 0.375141579671
# 60 New best found: 0.37474459964
# 61 New best found: 0.374697267065
# 62 New best found: 0.374201102077
# 63 New best found: 0.374091176529
# 66 New best found: 0.373693837312
# 67 New best found: 0.373523109637
# 70 New best found: 0.372323017858
# 71 New best found: 0.372166616924
# 73 New best found: 0.371513850137
# 80 New best found: 0.371277194232
# 82 New best found: 0.370723286988
# 83 New best found: 0.37040368401
# 87 New best found: 0.36993950148
# 91 New best found: 0.369650598475
# 96 New best found: 0.36913769074
# 98 New best found: 0.36911571421
# 100 New best found: 0.368216002292
# 109 New best found: 0.368073430235
# 113 New best found: 0.367744560345
# 114 New best found: 0.367656506845
# 118 New best found: 0.367355572887
# 123 New best found: 0.366966521683
# 125 New best found: 0.36693502328
# 134 New best found: 0.366474761107
# 137 New best found: 0.36634749418
# 138 New best found: 0.366119755337
# 142 New best found: 0.366059921806
# 143 New best found: 0.365891712227
# 147 New best found: 0.365584520561
# 149 New best found: 0.365570454531
# 151 New best found: 0.365269788277
# 152 New best found: 0.365236244402
# 159 New best found: 0.365180393224
# 165 New best found: 0.364938391237
# 170 New best found: 0.364556986675
# 172 New best found: 0.364546631694
# 179 New best found: 0.36443902819
# 181 New best found: 0.364211911815
# 186 New best found: 0.364131893232
# 190 New best found: 0.363756079656
# 195 New best found: 0.363741852421
# 204 New best found: 0.363647625807
# Early stopping after 214 epochs
# Score is: {'loss': 0.36364762580673882, 'AUC': 0.093918011790085298, 'wAUC': 0.070765520434920681}
# Fold took 341.698s
#
# Running fold 2 / 10
# 1 New best found: 0.511894093413
# 2 New best found: 0.483119718494
# 3 New best found: 0.466808839908
# 4 New best found: 0.455920511833
# 5 New best found: 0.447132867042
# 6 New best found: 0.439550702597
# 7 New best found: 0.43359878528
# 8 New best found: 0.426849344398
# 9 New best found: 0.421442991174
# 10 New best found: 0.416589437778
# 11 New best found: 0.412533640411
# 12 New best found: 0.408238181816
# 13 New best found: 0.405598137603
# 14 New best found: 0.402344997041
# 15 New best found: 0.400171629097
# 16 New best found: 0.398956703807
# 17 New best found: 0.396753279253
# 18 New best found: 0.395059052534
# 19 New best found: 0.394252036242
# 20 New best found: 0.392823439045
# 21 New best found: 0.391757171405
# 22 New best found: 0.390732168475
# 23 New best found: 0.389315935987
# 24 New best found: 0.388488454758
# 26 New best found: 0.387709688328
# 27 New best found: 0.386744651926
# 28 New best found: 0.386731201631
# 29 New best found: 0.386659916915
# 30 New best found: 0.386003732878
# 31 New best found: 0.384152038867
# 32 New best found: 0.384084381308
# 33 New best found: 0.383744778388
# 34 New best found: 0.383539124872
# 35 New best found: 0.382315195787
# 36 New best found: 0.382012576185
# 37 New best found: 0.381646210071
# 38 New best found: 0.381477772893
# 39 New best found: 0.381279742714
# 41 New best found: 0.37988784211
# 44 New best found: 0.379599863234
# 45 New best found: 0.379462875387
# 46 New best found: 0.3790337965
# 48 New best found: 0.378307758489
# 49 New best found: 0.378200385963
# 50 New best found: 0.377825906812
# 54 New best found: 0.377457435614
# 55 New best found: 0.377033691459
# 57 New best found: 0.376086334573
# 59 New best found: 0.376079265509
# 60 New best found: 0.375907656486
# 63 New best found: 0.375811989539
# 64 New best found: 0.37531535713
# 66 New best found: 0.374845939158
# 67 New best found: 0.374694873865
# 68 New best found: 0.374408130856
# 71 New best found: 0.374181594175
# 75 New best found: 0.374030199234
# 77 New best found: 0.373474725221
# 81 New best found: 0.373252661863
# 82 New best found: 0.372679756702
# 86 New best found: 0.372553636425
# 87 New best found: 0.372414820818
# 93 New best found: 0.371996421988
# 95 New best found: 0.371718564417
# 96 New best found: 0.37168129278
# 98 New best found: 0.371650381384
# 100 New best found: 0.37141648161
# 102 New best found: 0.370990330699
# 107 New best found: 0.370824010193
# 112 New best found: 0.370782756439
# 113 New best found: 0.370613813499
# 119 New best found: 0.370413839211
# 121 New best found: 0.369487428298
# 131 New best found: 0.36908473746
# 140 New best found: 0.368975280297
# 150 New best found: 0.368762894692
# 157 New best found: 0.368379157978
# 159 New best found: 0.368367391114
# 168 New best found: 0.368322446746
# 176 New best found: 0.367784506078
# 185 New best found: 0.367470585484
# 195 New best found: 0.367338313524
# 203 New best found: 0.367241880304
# 213 New best found: 0.367044700102
# 222 New best found: 0.366849480371
# 224 New best found: 0.366833355578
# 230 New best found: 0.366793874187
# 236 New best found: 0.366645035243
# 239 New best found: 0.366644686926
# 244 New best found: 0.36658785681
# 248 New best found: 0.36649169569
# 253 New best found: 0.366173338622
# 262 New best found: 0.366065986382
# 264 New best found: 0.366065184214
# 265 New best found: 0.365920332402
# Early stopping after 275 epochs
# Score is: {'loss': 0.36592033240168403, 'AUC': 0.095294211742225521, 'wAUC': 0.070801126310961138}
# Fold took 403.701s
#
# Running fold 3 / 10
# 1 New best found: 0.496043220613
# 2 New best found: 0.474068903932
# 3 New best found: 0.460391111097
# 4 New best found: 0.451672431987
# 5 New best found: 0.444124488151
# 6 New best found: 0.437260417007
# 7 New best found: 0.431391740097
# 8 New best found: 0.426022949264
# 9 New best found: 0.419738383466
# 10 New best found: 0.414870360906
# 11 New best found: 0.410111591722
# 12 New best found: 0.406217373499
# 13 New best found: 0.402782426981
# 14 New best found: 0.400393385195
# 15 New best found: 0.397269363464
# 16 New best found: 0.396497891888
# 17 New best found: 0.394577468926
# 18 New best found: 0.393138522713
# 19 New best found: 0.391319361149
# 20 New best found: 0.390588144334
# 21 New best found: 0.390072040869
# 22 New best found: 0.388114634758
# 24 New best found: 0.386596408726
# 26 New best found: 0.385224381264
# 28 New best found: 0.384383351691
# 29 New best found: 0.38365497079
# 30 New best found: 0.383090948296
# 31 New best found: 0.382918885988
# 33 New best found: 0.382403104465
# 34 New best found: 0.38219841061
# 35 New best found: 0.380885153825
# 37 New best found: 0.380764616159
# 38 New best found: 0.380070314015
# 39 New best found: 0.379272418884
# 42 New best found: 0.378610337628
# 44 New best found: 0.378229793553
# 46 New best found: 0.377719075067
# 49 New best found: 0.376951079806
# 51 New best found: 0.376746773424
# 53 New best found: 0.376556362645
# 55 New best found: 0.376145302219
# 56 New best found: 0.375876764282
# 57 New best found: 0.375853736936
# 60 New best found: 0.375056576753
# 64 New best found: 0.374816554755
# 65 New best found: 0.374271142919
# 67 New best found: 0.373968584916
# 69 New best found: 0.373784225281
# 73 New best found: 0.373284346031
# 75 New best found: 0.373061101201
# 80 New best found: 0.372701323246
# 83 New best found: 0.372619560609
# 85 New best found: 0.372411529896
# 87 New best found: 0.372229476524
# 89 New best found: 0.372121668737
# 91 New best found: 0.371726513033
# 96 New best found: 0.371198887426
# 100 New best found: 0.371097996331
# 109 New best found: 0.371002221509
# 110 New best found: 0.370972483747
# 112 New best found: 0.37053476596
# 119 New best found: 0.370102388892
# 126 New best found: 0.369721914871
# 127 New best found: 0.369367522759
# 132 New best found: 0.36929093491
# 136 New best found: 0.369041125124
# 139 New best found: 0.368643723123
# 146 New best found: 0.368524786424
# 147 New best found: 0.368397469199
# 157 New best found: 0.368338050778
# 163 New best found: 0.368180552466
# 166 New best found: 0.367838791553
# 175 New best found: 0.367420392482
# Early stopping after 185 epochs
# Score is: {'loss': 0.3674203924823557, 'AUC': 0.095963787957218716, 'wAUC': 0.069943000433268621}
# Fold took 291.272s
#
# Running fold 4 / 10
# 1 New best found: 0.502706155213
# 2 New best found: 0.479456194885
# 3 New best found: 0.464545972073
# 4 New best found: 0.453955183076
# 5 New best found: 0.446233420655
# 6 New best found: 0.438049132904
# 7 New best found: 0.431823976865
# 8 New best found: 0.425963815898
# 9 New best found: 0.419668655487
# 10 New best found: 0.41488957895
# 11 New best found: 0.409459787438
# 12 New best found: 0.405427310859
# 13 New best found: 0.401759048288
# 14 New best found: 0.399412171414
# 15 New best found: 0.396416834383
# 16 New best found: 0.394557311859
# 17 New best found: 0.393591276533
# 18 New best found: 0.392044086462
# 19 New best found: 0.390289527553
# 20 New best found: 0.389492258029
# 21 New best found: 0.387839812265
# 22 New best found: 0.387226636452
# 23 New best found: 0.386940143355
# 24 New best found: 0.385603275261
# 25 New best found: 0.385294410541
# 26 New best found: 0.384841137517
# 27 New best found: 0.383938105014
# 29 New best found: 0.383601154804
# 30 New best found: 0.382086428667
# 31 New best found: 0.381494641317
# 32 New best found: 0.381097610062
# 33 New best found: 0.381073899326
# 34 New best found: 0.380267222373
# 35 New best found: 0.380002055412
# 36 New best found: 0.379305172469
# 37 New best found: 0.378797671427
# 38 New best found: 0.378400808931
# 40 New best found: 0.378114611982
# 41 New best found: 0.377381044417
# 44 New best found: 0.37680652137
# 45 New best found: 0.376392849269
# 46 New best found: 0.376051480353
# 48 New best found: 0.375293602633
# 49 New best found: 0.375175178201
# 50 New best found: 0.374824391459
# 53 New best found: 0.374356616584
# 55 New best found: 0.374061025542
# 56 New best found: 0.37376389904
# 57 New best found: 0.37343552116
# 59 New best found: 0.373150669522
# 63 New best found: 0.372969925786
# 65 New best found: 0.372940509476
# 66 New best found: 0.37266670278
# 67 New best found: 0.372615558009
# 68 New best found: 0.372317697336
# 70 New best found: 0.37223660342
# 71 New best found: 0.372172220094
# 73 New best found: 0.371919231843
# 75 New best found: 0.371464169223
# 76 New best found: 0.371247639945
# 81 New best found: 0.370656299798
# 84 New best found: 0.37060165299
# 85 New best found: 0.36988463864
# 91 New best found: 0.369714971194
# 94 New best found: 0.369410206493
# 101 New best found: 0.368995789632
# 102 New best found: 0.368690620083
# 110 New best found: 0.368526309146
# 112 New best found: 0.368134480008
# 120 New best found: 0.367874257498
# 121 New best found: 0.367767887754
# 128 New best found: 0.367512768714
# 131 New best found: 0.367251194947
# 138 New best found: 0.366793698338
# 146 New best found: 0.366717755326
# 153 New best found: 0.366480700058
# 154 New best found: 0.36635513158
# 156 New best found: 0.366217911246
# Early stopping after 166 epochs
# Score is: {'loss': 0.36621791124606928, 'AUC': 0.095406764290013268, 'wAUC': 0.073927921126842544}
# Fold took 253.935s
#
# Running fold 5 / 10
# 1 New best found: 0.50051481205
# 2 New best found: 0.477073230189
# 3 New best found: 0.46419564873
# 4 New best found: 0.454631092596
# 5 New best found: 0.445531728075
# 6 New best found: 0.437260885369
# 7 New best found: 0.430730056624
# 8 New best found: 0.423859546143
# 9 New best found: 0.416708305138
# 10 New best found: 0.411523535714
# 11 New best found: 0.407052279937
# 12 New best found: 0.40255038778
# 13 New best found: 0.400491073081
# 14 New best found: 0.398196461016
# 15 New best found: 0.395512378034
# 16 New best found: 0.394430604588
# 17 New best found: 0.392047533394
# 18 New best found: 0.391096681326
# 19 New best found: 0.390295860685
# 20 New best found: 0.389520183044
# 21 New best found: 0.388422319081
# 22 New best found: 0.387284036607
# 23 New best found: 0.386876907341
# 24 New best found: 0.38535485969
# 25 New best found: 0.384659601875
# 26 New best found: 0.383781576604
# 27 New best found: 0.383438726147
# 28 New best found: 0.382895454636
# 30 New best found: 0.382217191899
# 31 New best found: 0.381640497353
# 32 New best found: 0.381017435687
# 33 New best found: 0.380381950267
# 34 New best found: 0.380019444817
# 35 New best found: 0.379650319917
# 36 New best found: 0.379065434793
# 38 New best found: 0.378537571267
# 39 New best found: 0.378455071688
# 40 New best found: 0.377992687843
# 42 New best found: 0.37724727843
# 44 New best found: 0.37681434685
# 45 New best found: 0.376066184499
# 46 New best found: 0.376051225434
# 47 New best found: 0.375960282092
# 48 New best found: 0.375937887336
# 49 New best found: 0.375419515966
# 50 New best found: 0.375085034904
# 51 New best found: 0.374505644757
# 54 New best found: 0.373996750931
# 57 New best found: 0.373647718144
# 58 New best found: 0.37349320217
# 60 New best found: 0.372848709481
# 66 New best found: 0.372524342005
# 68 New best found: 0.372252270365
# 69 New best found: 0.371800488305
# 71 New best found: 0.371683956455
# 75 New best found: 0.371675196012
# 76 New best found: 0.371233031732
# 80 New best found: 0.371097649808
# 81 New best found: 0.370947857054
# 85 New best found: 0.370861532938
# 87 New best found: 0.370227889631
# 93 New best found: 0.369967163904
# 96 New best found: 0.369360030278
# 97 New best found: 0.369247793881
# 99 New best found: 0.36899712867
# 108 New best found: 0.36857019392
# 114 New best found: 0.368032590074
# 123 New best found: 0.36764543132
# 132 New best found: 0.367067007041
# Early stopping after 142 epochs
# Score is: {'loss': 0.36706700704050571, 'AUC': 0.095584286054199552, 'wAUC': 0.071179136376626762}
# Fold took 222.273s
#
# Running fold 6 / 10
# 1 New best found: 0.492201238941
# 2 New best found: 0.473664800703
# 3 New best found: 0.460915287438
# 4 New best found: 0.451834796862
# 5 New best found: 0.442679092178
# 6 New best found: 0.434902772645
# 7 New best found: 0.426486343616
# 8 New best found: 0.418697016827
# 9 New best found: 0.411253344215
# 10 New best found: 0.406171008456
# 11 New best found: 0.401375304794
# 12 New best found: 0.396922568184
# 13 New best found: 0.394494406515
# 14 New best found: 0.391984129673
# 15 New best found: 0.390031951283
# 16 New best found: 0.389016946189
# 17 New best found: 0.387352442989
# 18 New best found: 0.386095985101
# 19 New best found: 0.385551339851
# 20 New best found: 0.384208281072
# 21 New best found: 0.382971273551
# 22 New best found: 0.382692696694
# 23 New best found: 0.381167649094
# 24 New best found: 0.38072202849
# 25 New best found: 0.379644161966
# 26 New best found: 0.378906591792
# 27 New best found: 0.378599538782
# 28 New best found: 0.37787703923
# 29 New best found: 0.377104970964
# 30 New best found: 0.376135769703
# 32 New best found: 0.375643434264
# 33 New best found: 0.374188909259
# 36 New best found: 0.373364682697
# 37 New best found: 0.372816013915
# 38 New best found: 0.372694232823
# 39 New best found: 0.372118502457
# 41 New best found: 0.37129210997
# 42 New best found: 0.370984397621
# 45 New best found: 0.370157843479
# 47 New best found: 0.369863204545
# 48 New best found: 0.369583630016
# 50 New best found: 0.369238776396
# 51 New best found: 0.368572788467
# 52 New best found: 0.368067469134
# 54 New best found: 0.367995868855
# 55 New best found: 0.367744634973
# 57 New best found: 0.367444438421
# 58 New best found: 0.366986288541
# 60 New best found: 0.366727272746
# 63 New best found: 0.366226512933
# 65 New best found: 0.366112536507
# 66 New best found: 0.365743966246
# 68 New best found: 0.365204720809
# 70 New best found: 0.365153819644
# 73 New best found: 0.364640872196
# 76 New best found: 0.364315465572
# 77 New best found: 0.363951107911
# 78 New best found: 0.363887477888
# 81 New best found: 0.363608030875
# 84 New best found: 0.363518338827
# 87 New best found: 0.363442450723
# 90 New best found: 0.362845020117
# 95 New best found: 0.362609687599
# 96 New best found: 0.36241749171
# 99 New best found: 0.362050044785
# 104 New best found: 0.361967269181
# 105 New best found: 0.361508527909
# 111 New best found: 0.361338084357
# 114 New best found: 0.36120996411
# 117 New best found: 0.361086242852
# 124 New best found: 0.360733058442
# 128 New best found: 0.36054335886
# 133 New best found: 0.360335173232
# 136 New best found: 0.360254347406
# 138 New best found: 0.360215050312
# 140 New best found: 0.360132471575
# 144 New best found: 0.360118541896
# 148 New best found: 0.359804625081
# 149 New best found: 0.359482771763
# 154 New best found: 0.359448060655
# Early stopping after 164 epochs
# Score is: {'loss': 0.3594480606552039, 'AUC': 0.09184135782647973, 'wAUC': 0.067906556219800684}
# Fold took 247.430s
#
# Running fold 7 / 10
# 1 New best found: 0.49864308326
# 2 New best found: 0.477095449641
# 3 New best found: 0.465755889342
# 4 New best found: 0.455469031504
# 5 New best found: 0.447029950911
# 6 New best found: 0.438375499819
# 7 New best found: 0.430879268978
# 8 New best found: 0.424122596354
# 9 New best found: 0.419122777922
# 10 New best found: 0.412788518039
# 11 New best found: 0.407052526648
# 12 New best found: 0.403618753485
# 13 New best found: 0.400573210699
# 14 New best found: 0.397672655215
# 15 New best found: 0.395205635037
# 16 New best found: 0.393470968482
# 17 New best found: 0.392345674082
# 18 New best found: 0.391171530491
# 19 New best found: 0.390305082749
# 20 New best found: 0.388924654808
# 21 New best found: 0.388013692833
# 22 New best found: 0.387656316685
# 23 New best found: 0.386104503291
# 24 New best found: 0.385109633965
# 25 New best found: 0.384731261471
# 26 New best found: 0.384520982084
# 27 New best found: 0.383881327981
# 28 New best found: 0.383534113544
# 29 New best found: 0.382959486283
# 30 New best found: 0.382391972724
# 31 New best found: 0.381422658445
# 32 New best found: 0.381089388157
# 33 New best found: 0.38054924041
# 34 New best found: 0.379990602895
# 36 New best found: 0.379724868476
# 37 New best found: 0.379709513036
# 38 New best found: 0.378935865552
# 39 New best found: 0.378029273887
# 41 New best found: 0.377423761487
# 42 New best found: 0.37715838398
# 43 New best found: 0.376945868618
# 47 New best found: 0.376390949431
# 48 New best found: 0.376245843807
# 50 New best found: 0.375522849334
# 52 New best found: 0.375206548707
# 53 New best found: 0.37502544929
# 54 New best found: 0.374959782956
# 55 New best found: 0.374786181579
# 56 New best found: 0.374406596457
# 57 New best found: 0.374054740585
# 60 New best found: 0.373747124259
# 61 New best found: 0.373650995901
# 62 New best found: 0.373419262654
# 67 New best found: 0.373137954903
# 69 New best found: 0.372579893494
# 75 New best found: 0.371817214198
# 78 New best found: 0.371651673802
# 80 New best found: 0.371401590876
# 81 New best found: 0.371184396568
# 82 New best found: 0.37109478398
# 83 New best found: 0.370921600563
# 87 New best found: 0.370776321216
# 88 New best found: 0.370729679961
# 95 New best found: 0.370411200269
# 96 New best found: 0.370296957915
# 97 New best found: 0.369932205501
# 105 New best found: 0.369367925943
# 110 New best found: 0.368951268177
# 114 New best found: 0.368782387339
# 122 New best found: 0.368528759439
# 123 New best found: 0.368300451492
# 132 New best found: 0.36803682366
# 133 New best found: 0.367797112435
# 138 New best found: 0.367773662335
# 140 New best found: 0.367724656427
# 141 New best found: 0.367376589757
# 142 New best found: 0.367266344358
# 150 New best found: 0.367258298555
# 152 New best found: 0.367171077658
# 159 New best found: 0.36662180135
# 160 New best found: 0.366519794072
# 170 New best found: 0.366500494268
# 174 New best found: 0.366462178297
# 183 New best found: 0.366157305985
# 185 New best found: 0.365805355787
# 186 New best found: 0.365674201186
# 192 New best found: 0.365538988491
# 195 New best found: 0.365395810088
# Early stopping after 205 epochs
# Score is: {'loss': 0.36539581008789918, 'AUC': 0.095114593053123753, 'wAUC': 0.073086195567940271}
# Fold took 302.407s
#
# Running fold 8 / 10
# 1 New best found: 0.495246397645
# 2 New best found: 0.46767140963
# 3 New best found: 0.448965454174
# 4 New best found: 0.436464843531
# 5 New best found: 0.425806190039
# 6 New best found: 0.417529585953
# 7 New best found: 0.411829331026
# 8 New best found: 0.405648085238
# 9 New best found: 0.403048220382
# 10 New best found: 0.401351523603
# 11 New best found: 0.399836716204
# 12 New best found: 0.396624244531
# 13 New best found: 0.396303206669
# 14 New best found: 0.394634642581
# 15 New best found: 0.393809767222
# 16 New best found: 0.393420308076
# 17 New best found: 0.391139309838
# 18 New best found: 0.390087438572
# 20 New best found: 0.389149087693
# 21 New best found: 0.388635296737
# 23 New best found: 0.387139640645
# 24 New best found: 0.38637460962
# 26 New best found: 0.385481948557
# 27 New best found: 0.385256754835
# 28 New best found: 0.384672817788
# 29 New best found: 0.38434954749
# 30 New best found: 0.383067749758
# 33 New best found: 0.382648482967
# 34 New best found: 0.382624033349
# 35 New best found: 0.381434206603
# 37 New best found: 0.380492078922
# 38 New best found: 0.380364101169
# 40 New best found: 0.380356265774
# 41 New best found: 0.380348673676
# 42 New best found: 0.379102154593
# 44 New best found: 0.378963785797
# 45 New best found: 0.378239773735
# 47 New best found: 0.377715300161
# 48 New best found: 0.377173803348
# 50 New best found: 0.376669656175
# 53 New best found: 0.376156216645
# 56 New best found: 0.375396779363
# 59 New best found: 0.375345357375
# 60 New best found: 0.375234130239
# 61 New best found: 0.374968357143
# 63 New best found: 0.374491536744
# 66 New best found: 0.373796783769
# 71 New best found: 0.373540811064
# 72 New best found: 0.373289200995
# 75 New best found: 0.373197954086
# 79 New best found: 0.373028499745
# 81 New best found: 0.372600185008
# 84 New best found: 0.372151190514
# 86 New best found: 0.37206565413
# 92 New best found: 0.371904842361
# 95 New best found: 0.371566867558
# 99 New best found: 0.371487207752
# 102 New best found: 0.370991266187
# 111 New best found: 0.37062771584
# 113 New best found: 0.370592611319
# 116 New best found: 0.370525841009
# 117 New best found: 0.37044891104
# 118 New best found: 0.370171278341
# 120 New best found: 0.369568900169
# 129 New best found: 0.369038124845
# 138 New best found: 0.36872495525
# Early stopping after 148 epochs
# Score is: {'loss': 0.36872495525035015, 'AUC': 0.097017513997099458, 'wAUC': 0.07161263366767201}
# Fold took 225.319s
#
# Running fold 9 / 10
# 1 New best found: 0.504189524805
# 2 New best found: 0.484116807239
# 3 New best found: 0.470341821654
# 4 New best found: 0.462118082438
# 5 New best found: 0.45360818771
# 6 New best found: 0.447474837566
# 7 New best found: 0.441874872164
# 8 New best found: 0.435709962191
# 9 New best found: 0.428385857851
# 10 New best found: 0.42375037901
# 11 New best found: 0.418001777285
# 12 New best found: 0.413574224021
# 13 New best found: 0.40964500683
# 14 New best found: 0.406666390252
# 15 New best found: 0.404013551073
# 16 New best found: 0.403025798309
# 17 New best found: 0.401634029716
# 18 New best found: 0.399349577408
# 19 New best found: 0.398600916503
# 20 New best found: 0.398284406422
# 21 New best found: 0.396218438842
# 22 New best found: 0.395413870955
# 23 New best found: 0.394198107947
# 24 New best found: 0.393360845742
# 25 New best found: 0.393061020574
# 26 New best found: 0.39275285375
# 27 New best found: 0.391832591095
# 28 New best found: 0.390887082679
# 29 New best found: 0.390846889017
# 30 New best found: 0.38928693944
# 31 New best found: 0.389085927553
# 32 New best found: 0.388391533187
# 33 New best found: 0.38754439579
# 34 New best found: 0.387504550986
# 35 New best found: 0.387479722175
# 36 New best found: 0.38620247099
# 37 New best found: 0.385770648907
# 38 New best found: 0.385525612997
# 39 New best found: 0.385189821762
# 40 New best found: 0.384466347265
# 41 New best found: 0.383992874132
# 42 New best found: 0.383989834311
# 43 New best found: 0.383966878635
# 44 New best found: 0.383161277478
# 45 New best found: 0.382760799226
# 47 New best found: 0.381882447591
# 48 New best found: 0.381317853519
# 50 New best found: 0.380342232526
# 54 New best found: 0.379356860214
# 56 New best found: 0.378986929373
# 57 New best found: 0.37856347047
# 58 New best found: 0.378291091634
# 61 New best found: 0.378047900421
# 62 New best found: 0.377936149735
# 63 New best found: 0.377189750974
# 65 New best found: 0.376814553232
# 66 New best found: 0.376524373817
# 68 New best found: 0.376152776191
# 69 New best found: 0.375584042127
# 74 New best found: 0.375325320456
# 75 New best found: 0.374969881323
# 77 New best found: 0.374801929232
# 78 New best found: 0.374654018211
# 80 New best found: 0.3743308288
# 81 New best found: 0.374143109803
# 84 New best found: 0.373677638914
# 87 New best found: 0.373606186294
# 90 New best found: 0.373445273852
# 92 New best found: 0.373246125033
# 93 New best found: 0.372560677101
# 95 New best found: 0.372274989115
# 102 New best found: 0.372093113536
# 104 New best found: 0.3720888551
# 105 New best found: 0.371401003463
# 111 New best found: 0.371192363109
# 113 New best found: 0.371039750433
# 119 New best found: 0.370354294827
# 122 New best found: 0.370285571809
# 131 New best found: 0.369842098531
# 132 New best found: 0.369653278219
# 135 New best found: 0.369512576832
# 140 New best found: 0.369229450904
# 141 New best found: 0.369059198029
# 148 New best found: 0.368775886011
# 149 New best found: 0.368621443897
# 156 New best found: 0.368332549324
# Early stopping after 166 epochs
# Score is: {'loss': 0.36833254932408799, 'AUC': 0.096398951739858685, 'wAUC': 0.070870550588834735}
# Fold took 244.043s
#
# Running fold 10 / 10
# 1 New best found: 0.504674699621
# 2 New best found: 0.484125059885
# 3 New best found: 0.469780179364
# 4 New best found: 0.459873888935
# 5 New best found: 0.450377073767
# 6 New best found: 0.441623894672
# 7 New best found: 0.43508826482
# 8 New best found: 0.428386656421
# 9 New best found: 0.422336343928
# 10 New best found: 0.416681977114
# 11 New best found: 0.412960014429
# 12 New best found: 0.410452569316
# 13 New best found: 0.406961819872
# 14 New best found: 0.404706054448
# 15 New best found: 0.402411067956
# 16 New best found: 0.402095010168
# 17 New best found: 0.399516592608
# 18 New best found: 0.398649817912
# 19 New best found: 0.398378677161
# 20 New best found: 0.397489632977
# 21 New best found: 0.39611803941
# 22 New best found: 0.395197801287
# 23 New best found: 0.394488722733
# 24 New best found: 0.393579905431
# 25 New best found: 0.393221728301
# 26 New best found: 0.392177301415
# 27 New best found: 0.391474878196
# 28 New best found: 0.391382925336
# 29 New best found: 0.391236389697
# 30 New best found: 0.39058671656
# 31 New best found: 0.390168952201
# 33 New best found: 0.390126272312
# 34 New best found: 0.389443112011
# 35 New best found: 0.38851836274
# 36 New best found: 0.387942821694
# 37 New best found: 0.387393564377
# 40 New best found: 0.387312518541
# 41 New best found: 0.387107441413
# 42 New best found: 0.386398663322
# 44 New best found: 0.38578225747
# 46 New best found: 0.385426854704
# 48 New best found: 0.385113775653
# 50 New best found: 0.385031972208
# 51 New best found: 0.384131823397
# 53 New best found: 0.383993010677
# 54 New best found: 0.383626905443
# 59 New best found: 0.383134553631
# 60 New best found: 0.383075248012
# 62 New best found: 0.383064619748
# 64 New best found: 0.382127591772
# 66 New best found: 0.382071111778
# 68 New best found: 0.382064135824
# 69 New best found: 0.381566861826
# 72 New best found: 0.380897318097
# 78 New best found: 0.380832784095
# 79 New best found: 0.380741112265
# 80 New best found: 0.380735489669
# 81 New best found: 0.38003678968
# 88 New best found: 0.380017848879
# 89 New best found: 0.379216513619
# 90 New best found: 0.378887891542
# 96 New best found: 0.378826130633
# 99 New best found: 0.378629012553
# 101 New best found: 0.378607277912
# 102 New best found: 0.37860585677
# 103 New best found: 0.378501739918
# 104 New best found: 0.378382805436
# 105 New best found: 0.377881016319
# 109 New best found: 0.377760012348
# 116 New best found: 0.377387873343
# 117 New best found: 0.377317527652
# 125 New best found: 0.376986703827
# 126 New best found: 0.376859567477
# 134 New best found: 0.376481182106
# 135 New best found: 0.376435596955
# 143 New best found: 0.3761346017
# 147 New best found: 0.375885629665
# Early stopping after 157 epochs
# Score is: {'loss': 0.37588562966531208, 'AUC': 0.10118106547018346, 'wAUC': 0.074566461013998331}
# Fold took 242.414s
#
#
# ______________________________________
# Training finished
# Cross-validation took 2774.787s
# Mean wAUC = 0.0715 +- 0.0006
# ______________________________________

# %% [markdown]
# ## Construct ensemble

# %%
with open('train_weights/resultsFile.pkl', 'r') as fin:   
    results = pickle.load(fin)

# %%
ensemble, weights = assembleEnsemble(results, ensembleSize, ensembleMode, compileArgs)

# %% [markdown]
# ## Response on development data

# %%
batchEnsemblePredict(ensemble, weights, trainData, ensembleSize=10, verbose=1)

# %%
print 'Training ROC AUC: unweighted {}, weighted {}'.format(roc_auc_score(getFeature('targets', trainData), getFeature('pred', trainData)),
                                                            roc_auc_score(getFeature('targets', trainData), getFeature('pred', trainData), sample_weight=getFeature('weights', trainData)))

# %% [markdown]
# ## Response on val data

# %%
batchEnsemblePredict(ensemble, weights, testData, ensembleSize=10, verbose=1)

# %%
print 'Testing ROC AUC: unweighted {}, weighted {}'.format(roc_auc_score(getFeature('targets', testData), getFeature('pred', testData)),
                                                           roc_auc_score(getFeature('targets', testData), getFeature('pred', testData), sample_weight=getFeature('weights', testData)))

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ### Import in dataframe

# %%
def convertToDF(datafile, columns={'gen_target', 'gen_weight', 'gen_sample', 'pred_class'}, nLoad=-1):
    data = pandas.DataFrame()
    data['gen_target'] = getFeature('targets', datafile, nLoad)
    data['gen_weight'] = getFeature('weights', datafile, nLoad)
    data['gen_sample'] = getFeature('gen_sample', datafile, nLoad)
    data['pred_class'] = getFeature('pred', datafile, nLoad)
    print len(data), "candidates loaded"
    return data

# %%
devData = convertToDF(trainData)
valData = convertToDF(testData)

# %%
sigVal = (valData.gen_target == 1)
bkgVal = (valData.gen_target == 0)

# %% [markdown]
# ### ROC curve

# %%
rocPlot(inData=[devData, valData],
        params=[{'linestyle':'dashed', 'color':'b'}, {'color':'b'}],
        labels=['Train', 'Test'], weightName='gen_weight')

# %% [markdown]
# ### MVA distributions

# %%
getClassPredPlot([valData[bkgVal], valData[sigVal]], weightName='gen_weight')

# %%
getSamplePredPlot(valData)

# %% [markdown]
# ## Save classified data

# %%
name = dirLoc + signal + "_" + channel + "_" + varSet + '_' + classModel + '_classifiedData.csv'
print "Saving data to", name
valData.to_csv(name, columns=['gen_target', 'gen_weight', 'gen_sample', 'pred_class'])

# %% [markdown]
# ## Save/load

# %%
name = "weights/DNN_" + signal + "_" + channel + "_" + varSet + '_' + classModel
print name

# %% [markdown]
# ### Save

# %%
saveEnsemble(name, ensemble, weights, compileArgs, overwrite=1)

# %% [markdown]
# ### Load

# %%
ensemble, weights, compileArgs, inputPipe, outputPipe = loadEnsemble(name)
