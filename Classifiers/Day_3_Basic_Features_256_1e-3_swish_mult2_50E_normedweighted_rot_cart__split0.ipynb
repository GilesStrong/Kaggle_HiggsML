# %% [markdown]
# # Day 3
# batch size 256 lr 1e-3, normed weighted, rotated, cartesian, split ny jet mult (0)

# %% [markdown]
# ### Import modules

# %%
# %matplotlib inline
from __future__ import division
import sys
import os
os.environ['MKL_THREADING_LAYER']='GNU'
sys.path.append('../')
from Modules.Basics import *
from Modules.Class_Basics import *
# Out:
# /home/giles/anaconda2/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# /home/giles/anaconda2/lib/python2.7/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# Using TensorFlow backend.

# %% [markdown]
# ## Options

# %%
nJets = '0'
inputPipe, outputPipe = getPreProcPipes(normIn=True)
classModel = 'modelSwish'
varSet = "filtered_rot_cart_features"

nSplits = 10
ensembleSize = 10
ensembleMode = 'loss'

maxEpochs = 200
compileArgs = {'loss':'binary_crossentropy', 'optimizer':'adam'}
trainParams = {'epochs' : 1, 'batch_size' : 256, 'verbose' : 0}
modelParams = {'version':classModel, 'nIn':18, 'compileArgs':compileArgs}

# %% [markdown]
# ## Import data

# %%
trainData = h5py.File(dirLoc + 'train_' + nJets + '.hdf5', "r+")
valData = h5py.File(dirLoc + 'val_' + nJets + '.hdf5', "r+")

# %% [markdown]
# ## Determine LR

# %%
lrFinder = batchLRFindClassifier(trainData, nSplits, getClassifier, modelParams, trainParams, lrBounds=[1e-5,1e-1], trainOnWeights=True, verbose=0)
# Out:
# 2 classes found, running in binary mode
#
#
# ______________________________________
# Training finished
# Cross-validation took 1.101s
# ______________________________________

# %%
compileArgs['lr'] = 1e-3

# %% [markdown]
# ## Train classifier

# %%
results, histories = batchTrainClassifier(trainData, nSplits, getClassifier, modelParams, trainParams, patience=100, cosAnnealMult=2, trainOnWeights=True, maxEpochs=maxEpochs, verbose=1)
# Out:
# Using cosine annealing
# Training using weights
# Running fold 1 / 10
# 2 classes found, running in binary mode
# /home/giles/anaconda2/lib/python2.7/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.220625). Check your callbacks.
#   % delta_t_median)
# /home/giles/anaconda2/lib/python2.7/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.110677). Check your callbacks.
#   % delta_t_median)
# 1 New best found: 9.73894447297e-05
# 2 New best found: 8.46011855831e-05
# 3 New best found: 8.19349506066e-05
# 4 New best found: 7.99950279044e-05
# 5 New best found: 7.7461941964e-05
# 6 New best found: 7.73076704374e-05
# 7 New best found: 7.72924755956e-05
# 8 New best found: 7.67801437179e-05
# 11 New best found: 7.65250877082e-05
# 13 New best found: 7.59461740384e-05
# 14 New best found: 7.59200812588e-05
# 15 New best found: 7.59064727828e-05
# 22 New best found: 7.55004834061e-05
# 24 New best found: 7.53838123183e-05
# 25 New best found: 7.52002523177e-05
# 26 New best found: 7.48782856175e-05
# 29 New best found: 7.48466288367e-05
# 43 New best found: 7.48442104109e-05
# 44 New best found: 7.47590434667e-05
# 45 New best found: 7.45950371112e-05
# 53 New best found: 7.45721217977e-05
# 54 New best found: 7.44804249342e-05
# 56 New best found: 7.44767244429e-05
# 100 New best found: 7.43749431092e-05
# 107 New best found: 7.43213977373e-05
# Early stopping after 207 epochs
# Score is: {'loss': 7.432139773733007e-05, 'AUC': 0.10260164558593488, 'wAUC': 0.05517098350755956}
# Fold took 73.913s
#
# Running fold 2 / 10
# /home/giles/anaconda2/lib/python2.7/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.224396). Check your callbacks.
#   % delta_t_median)
# /home/giles/anaconda2/lib/python2.7/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.112560). Check your callbacks.
#   % delta_t_median)
# 1 New best found: 9
# 19 New best found: 7.50692143617e-05
# 22 New best found: 7.49832998022e-05
# 24 New best found: 7.45854904304e-05
# 26 New best found: 7.44037842334e-05
# 27 New best found: 7.42975512172e-05
# 28 New best found: 7.42430183533e-05
# 45 New best found: 7.40934698097e-05
# 51 New best found: 7.40921146216e-05
# 53 New best found: 7.39406103078e-05
# 54 New best found: 7.37949464983e-05
# 90 New best found: 7.3649196055e-05
# 99 New best found: 7.34237165812e-05
# Early stopping after 199 epochs
# Score is: {'loss': 7.342371658121192e-05, 'AUC': 0.09903153245601803, 'wAUC': 0.05403926816569071}
# Fold took 78.397s
#
#
# ______________________________________
# Training finished
# Cross-validation took 730.947s
# Mean wAUC = 0.0576 +- 0.0007
# ______________________________________

# %% [markdown]
# ## Construct ensemble

# %%
with open('train_weights/resultsFile.pkl', 'r') as fin:   
    results = pickle.load(fin)

# %%
ensemble, weights = assembleEnsemble(results, ensembleSize, ensembleMode, compileArgs)
# Out:
# Choosing ensemble by loss
# Model 0 is 9 with loss = 7.342371658121192e-05
# Model 1 is 6 with loss = 7.423174777979696e-05
# Model 2 is 0 with loss = 7.432139773733007e-05
# Model 3 is 1 with loss = 7.500304128241164e-05
# Model 4 is 7 with loss = 7.624628869522956e-05
# Model 5 is 8 with loss = 7.629357843561489e-05
# Model 6 is 3 with loss = 7.726304175364276e-05
# Model 7 is 4 with loss = 7.747052872487339e-05
# Model 8 is 5 with loss = 7.820227695377004e-05
# Model 9 is 2 with loss = 7.888064254682013e-05

# %% [markdown]
# ## Response on development data

# %%
batchEnsemblePredict(ensemble, weights, trainData, ensembleSize=10, verbose=1)
# Out:
# Predicting batch 1 out of 10
# Prediction took 0.000892510735037s per sample
#
# Predicting batch 2 out of 10
# Prediction took 0.000260650351073s per sample
#
# Predicting batch 3 out of 10
# Prediction took 0.000263057293103s per sample
#
# Predicting batch 4 out of 10
# Prediction took 0.000268090312657s per sample
#
# Predicting batch 5 out of 10
# Prediction took 0.000270327682953s per sample
#
# Predicting batch 6 out of 10
# Prediction took 0.000268819587752s per sample
#
# Predicting batch 7 out of 10
# Prediction took 0.000311959211898s per sample
#
# Predicting batch 8 out of 10
# Prediction took 0.000315873979687s per sample
#
# Predicting batch 9 out of 10
# Prediction took 0.000381399143685s per sample
#
# Predicting batch 10 out of 10
# Prediction took 0.000271370132884s per sample

# %%
print 'Training ROC AUC: unweighted {}, weighted {}'.format(roc_auc_score(getFeature('targets', trainData), getFeature('pred', trainData)),
                                                            roc_auc_score(getFeature('targets', trainData), getFeature('pred', trainData), sample_weight=getFeature('weights', trainData)))
# Out:
# Training ROC AUC: unweighted 0.899864007381, weighted 0.945416212176

# %% [markdown]
# ## Response on val data

# %%
batchEnsemblePredict(ensemble, weights, valData, ensembleSize=10, verbose=1)
# Out:
# Predicting batch 1 out of 10
# Prediction took 0.000304973978231s per sample
#
# Predicting batch 2 out of 10
# Prediction took 0.000292651828615s per sample
#
# Predicting batch 3 out of 10
# Prediction took 0.000410839937638s per sample
#
# Predicting batch 4 out of 10
# Prediction took 0.000289330069812s per sample
#
# Predicting batch 5 out of 10
# Prediction took 0.000282646835655s per sample
#
# Predicting batch 6 out of 10
# Prediction took 0.000282948916858s per sample
#
# Predicting batch 7 out of 10
# Prediction took 0.000287651180386s per sample
#
# Predicting batch 8 out of 10
# Prediction took 0.000287148568246s per sample
#
# Predicting batch 9 out of 10
# Prediction took 0.000285231356747s per sample
#
# Predicting batch 10 out of 10
# Prediction took 0.000288658996911s per sample

# %%
print 'Testing ROC AUC: unweighted {}, weighted {}'.format(roc_auc_score(getFeature('targets', valData), getFeature('pred', valData)),
                                                           roc_auc_score(getFeature('targets', valData), getFeature('pred', valData), sample_weight=getFeature('weights', valData)))
# Out:
# Testing ROC AUC: unweighted 0.898402916444, weighted 0.944024195918

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ### Import in dataframe

# %%
def convertToDF(datafile, columns={'gen_target', 'gen_weight', 'pred_class'}, nLoad=-1):
    data = pandas.DataFrame()
    data['gen_target'] = getFeature('targets', datafile, nLoad)
    data['gen_weight'] = getFeature('weights', datafile, nLoad)
    data['pred_class'] = getFeature('pred', datafile, nLoad)
    print len(data), "candidates loaded"
    return data

# %%
valData = convertToDF(valData)
# Out:
# 19983 candidates loaded

# %%
sigVal = (valData.gen_target == 1)
bkgVal = (valData.gen_target == 0)

# %% [markdown]
# ### MVA distributions

# %%
getClassPredPlot([valData[bkgVal], valData[sigVal]], weightName='gen_weight')

# %%
amsScan(valData)
# Out:
# [0.9729418158531189, 1.116594377455022]
# [0.37448444254652863,
#  0.5320220933815951,
#  0.41658559497402864,
#  0.6128664824366391,
#  0.7822487308329787,
#  1.0649679524806195,
#  0.47474673990885324,
#  0.4610503713700966,
#  1.0220206344239489,
#  0.013091469102170792,
#  0.33285547919036357,
#  0.476366574969762,
#  1.007650439848793,
#  0.32338539982674264,
#  0.3249451691922668,
#  0.8971430529635827,
#  0.5389861535038404,
#  0.550861036339902,
#  0.6477080450410304,
#  0.9675038043707896,
#  0.6351137655923786,
#  0.6024864996637208,
#  0.3169765129561735,
#  0.6534400713393105,
#  1.0712516399728405,
#  0.33052334536892997,
#  0.44057735314369567,
#  0.4765793308407267,
#  0.4707929115342449,
#  0.3369625845442039,
#  0.49920799728015036,
#  0.8603108791001254,
#  1.0467093178787248,
#  0.5061404514951277,
#  0.8772671946733189,
#  0.3295508554723448,
#  0.5813143718991649,
#  0.4093696610181279,
#  0.49734238302453443,
#  0.6848395289334888,
#  0.3997470369819922,
#  0.4940229395520761,
#  0.5533508757215654,
#  0.6008918054195684,
#  0.33143355041170974,
#  0.30871836351266424,
#  0.31045435231398616,
#  0.425510943857033,
#  0.4118101715234967,
#  0.416198742524795,
#  0.4064465569210664,
#  1.066879633291944,
#  0.43847277492265113,
#  0.43986686942376735,
#  0.49155666715339774,
#  0.3781019440935867,
#  0.3879499076572357,
#  0.6792422657519286,
#  0.3520262429068871,
#  0.3208935289144503,
#  0.4620011216596891,
#  0.35802767231891175,
#  0.3288614304768332,
#  0.3852126166605825,
#  0.5023055005570806,
#  0.33438464210483504,
#  0.8775650189967045,
#  1.108610404302949,
#  0.5594167669060692,
#  0.5023601064226902,
#  0.4761672388952534,
#  0.511074592949835,
#  0.31310998078129587,
#  0.34112694266528404,
#  0.3022571687807971,
#  0.4656523547613411,
#  0.38493499684746146,
#  0.44521563956094573,
#  0.5058812703435672,
#  0.443635076348433,
#  1.0090837955309286,
#  0.3929402446882081,
#  0.5116349900946667,
#  0.5064792912385575,
#  0.37931655499266176,
#  0.4861364514124396,
#  0.9336588081597813,
#  0.9034553806560468,
#  1.0141257898323548,
#  0.3101497516189764,
#  0.760743856593188,
#  1.0701410571319017,
#  0.3233439162270095,
#  0.41298736581593504,
#  0.3819800585033086,
#  1.0365757794879493,
#  0.30586169984251166,
#  0.33537925905864374,
#  0.44762546771250417,
#  0.40966219520156666,
#  0.5449960221662021,
#  0.6016641209330558,
#  0.4812647447880411,
#  0.6062683524633764,
#  0.3548261358773398,
#  0.3665891490598148,
#  0.6565868280825337,
#  1.0866360072077854,
#  0.6035668076127412,
#  1.0836746357021838,
#  0.5783642078145368,
#  0.5805195445967305,
#  0.8223192631917545,
#  1.0759227916875072,
#  ...]

# %%
def scoreTest(ensemble, weights, nJets):
    testData = h5py.File(dirLoc + 'testing_' + nJets + '.hdf5', "r+")
    batchEnsemblePredict(ensemble, weights, testData, ensembleSize=10, verbose=1)

def saveTest(cut, name, nJets):
    testData = h5py.File(dirLoc + 'testing_' + nJets + '.hdf5', "r+")
    
    data = pandas.DataFrame()
    data['EventId'] = getFeature('EventId', testData)
    data['pred_class'] = getFeature('pred', testData)
    
    data['Class'] = 'b'
    data.loc[data.pred_class >= cut, 'Class'] = 's'

    data.sort_values(by=['pred_class'], inplace=True)
    data['RankOrder']=range(1, len(data)+1)
    data.sort_values(by=['EventId'], inplace=True)

    print dirLoc + name + '_test.csv'
    data.to_csv(dirLoc + name + '_test.csv', columns=['EventId', 'RankOrder', 'Class'], index=False)

# %%
scoreTest(ensemble, weights, nJets)
# Out:
# Predicting batch 1 out of 10
# Prediction took 0.000291648569928s per sample
#
# Predicting batch 2 out of 10
# Prediction took 0.000288879087325s per sample
#
# Predicting batch 3 out of 10
# Prediction took 0.000285486051769s per sample
#
# Predicting batch 4 out of 10
# Prediction took 0.00028837300014s per sample
#
# Predicting batch 5 out of 10
# Prediction took 0.000286971836156s per sample
#
# Predicting batch 6 out of 10
# Prediction took 0.000282369727312s per sample
#
# Predicting batch 7 out of 10
# Prediction took 0.000290343449004s per sample
#
# Predicting batch 8 out of 10
# Prediction took 0.000285743816912s per sample
#
# Predicting batch 9 out of 10
# Prediction took 0.000309193277803s per sample
#
# Predicting batch 10 out of 10
# Prediction took 0.000294415993553s per sample

# %%
saveTest(0.9729418158531189, 'Day_2_Basic_Features_256_1e-3_swish_mult2_200E_normedweighted_rot_cart', nJets)

# %% [markdown]
# !kaggle competitions submit -c higgs-boson -f ../Data/Day_2_Basic_Features_256_1e-3_swish_mult2_200E_normedweighted_rot_cart_test.csv -m"Day2"
